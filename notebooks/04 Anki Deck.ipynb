# %%
# %load_ext autoreload
# %autoreload 2

from setup_imports import *  # noqa: F401,F403
from langcodes import Language
from src.phrases.search import get_phrases_by_collection
from src.anki_tools import create_anki_deck
from src.convert import get_collection_title

COLLECTION = "LM1000"
DECK = "Pack01"
collection_title = get_collection_title(COLLECTION)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Flash Card Creation

# %%
PHRASES = get_phrases_by_collection(COLLECTION)
print(len(PHRASES))
# Out:
# 1010

# %%
TARGET_LANGUAGE = Language.get("it-IT")
print(TARGET_LANGUAGE.display_name())
SOURCE_LANGUAGE = Language.get("en-GB")
print(SOURCE_LANGUAGE.display_name())
# Out:
# Italian (Italy)
# English (United Kingdom)

# %%
for i, p in enumerate(PHRASES):
    print(f"{i}: {p.english}")
    p.translate(target_language=TARGET_LANGUAGE, refine=True)
    p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
    p.upload(TARGET_LANGUAGE)
# Out:
# 0: A better option
# 2026-04-12 10:37:02 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una scelta migliore
# 2026-04-12 10:37:03 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_better_option_3c4781 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:03 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:03 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_better_option_3c4781.mp3 (local cache enabled)
# 2026-04-12 10:37:03 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_better_option_3c4781.mp3 (local cache enabled)
# 1: A bike in a low gear
# 2026-04-12 10:37:06 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una bici con una marcia bassa
# 2026-04-12 10:37:07 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_bike_in_a_low_gear_094264 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:07 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:07 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_bike_in_a_low_gear_094264.mp3 (local cache enabled)
# 2026-04-12 10:37:07 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_bike_in_a_low_gear_094264.mp3 (local cache enabled)
# 2: A bottle under the bench
# 2026-04-12 10:37:09 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una bottiglia sotto la panchina
# 2026-04-12 10:37:11 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_bottle_under_the_bench_24be43 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:11 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:11 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_bottle_under_the_bench_24be43.mp3 (local cache enabled)
# 2026-04-12 10:37:11 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_bottle_under_the_bench_24be43.mp3 (local cache enabled)
# 3: A boy and a girl
# 2026-04-12 10:37:13 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un ragazzo e una ragazza
# 2026-04-12 10:37:14 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_boy_and_a_girl_80d8a1 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:14 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_boy_and_a_girl_80d8a1.mp3 (local cache enabled)
# 2026-04-12 10:37:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_boy_and_a_girl_80d8a1.mp3 (local cache enabled)
# 4: A bright colour
# 2026-04-12 10:37:17 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un colore vivace
# 2026-04-12 10:37:17 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_bright_colour_33495c with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:18 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:18 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_bright_colour_33495c.mp3 (local cache enabled)
# 2026-04-12 10:37:18 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_bright_colour_33495c.mp3 (local cache enabled)
# 5: A card for each person
# 2026-04-12 10:37:21 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una carta per ogni persona
# 2026-04-12 10:37:22 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_card_for_each_person_5d861c with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:22 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:22 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_card_for_each_person_5d861c.mp3 (local cache enabled)
# 2026-04-12 10:37:22 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_card_for_each_person_5d861c.mp3 (local cache enabled)
# 6: A careful response
# 2026-04-12 10:37:24 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una risposta attenta
# 2026-04-12 10:37:25 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_careful_response_f94e87 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:25 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:25 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_careful_response_f94e87.mp3 (local cache enabled)
# 2026-04-12 10:37:25 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_careful_response_f94e87.mp3 (local cache enabled)
# 7: A change in the West
# 2026-04-12 10:37:28 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un cambiamento in Occidente
# 2026-04-12 10:37:28 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_change_in_the_west_ee1d05 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:28 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:28 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_change_in_the_west_ee1d05.mp3 (local cache enabled)
# 2026-04-12 10:37:29 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_change_in_the_west_ee1d05.mp3 (local cache enabled)
# 8: A cheap glass ring
# 2026-04-12 10:37:31 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un anello di vetro economico
# 2026-04-12 10:37:32 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_cheap_glass_ring_d80038 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:32 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:32 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_cheap_glass_ring_d80038.mp3 (local cache enabled)
# 2026-04-12 10:37:32 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_cheap_glass_ring_d80038.mp3 (local cache enabled)
# 9: A clean sheet of paper
# 2026-04-12 10:37:35 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un foglio di carta bianco
# 2026-04-12 10:37:35 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_clean_sheet_of_paper_1510d9 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:35 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:35 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_clean_sheet_of_paper_1510d9.mp3 (local cache enabled)
# 2026-04-12 10:37:36 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_clean_sheet_of_paper_1510d9.mp3 (local cache enabled)
# 10: A clean working environment
# 2026-04-12 10:37:38 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un ambiente di lavoro pulito
# 2026-04-12 10:37:39 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_clean_working_environment_1070c9 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:39 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:39 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_clean_working_environment_1070c9.mp3 (local cache enabled)
# 2026-04-12 10:37:39 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_clean_working_environment_1070c9.mp3 (local cache enabled)
# 11: A community with slightly different views
# 2026-04-12 10:37:41 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una comunità con punti di vista leggermente diversi
# 2026-04-12 10:37:42 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_community_with_slightly_different_views_cd8bdc with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:42 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:42 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_community_with_slightly_different_views_cd8bdc.mp3 (local cache enabled)
# 2026-04-12 10:37:42 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_community_with_slightly_different_views_cd8bdc.mp3 (local cache enabled)
# 12: A concerned doctor
# 2026-04-12 10:37:45 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un medico preoccupato
# 2026-04-12 10:37:46 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_concerned_doctor_394a53 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:46 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:46 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_concerned_doctor_394a53.mp3 (local cache enabled)
# 2026-04-12 10:37:46 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_concerned_doctor_394a53.mp3 (local cache enabled)
# 13: A conversation with Mum
# 2026-04-12 10:37:49 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una conversazione con la mamma
# 2026-04-12 10:37:50 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_conversation_with_mum_115456 with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:50 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:50 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_conversation_with_mum_115456.mp3 (local cache enabled)
# 2026-04-12 10:37:50 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_conversation_with_mum_115456.mp3 (local cache enabled)
# 14: A day in May is available.
# 2026-04-12 10:37:52 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: È disponibile un giorno a maggio.
# 2026-04-12 10:37:52 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_day_in_may_is_available_5c0eac with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:52 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:52 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_day_in_may_is_available_5c0eac.mp3 (local cache enabled)
# 2026-04-12 10:37:53 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_day_in_may_is_available_5c0eac.mp3 (local cache enabled)
# 15: A deep hole in the ground
# 2026-04-12 10:37:55 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una buca profonda nel terreno
# 2026-04-12 10:37:56 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_deep_hole_in_the_ground_54bcbb with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:56 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:56 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_deep_hole_in_the_ground_54bcbb.mp3 (local cache enabled)
# 2026-04-12 10:37:56 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_deep_hole_in_the_ground_54bcbb.mp3 (local cache enabled)
# 16: A difference on this side
# 2026-04-12 10:37:59 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una differenza su questo lato
# 2026-04-12 10:37:59 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_difference_on_this_side_e84d1a with it-IT translation to Firestore and GCS
# 2026-04-12 10:37:59 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:37:59 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_difference_on_this_side_e84d1a.mp3 (local cache enabled)
# 2026-04-12 10:37:59 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_difference_on_this_side_e84d1a.mp3 (local cache enabled)
# 17: A difficult job
# 2026-04-12 10:38:02 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un lavoro difficile
# 2026-04-12 10:38:03 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_difficult_job_20ca23 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:03 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:03 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_difficult_job_20ca23.mp3 (local cache enabled)
# 2026-04-12 10:38:03 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_difficult_job_20ca23.mp3 (local cache enabled)
# 18: A difficult word
# 2026-04-12 10:38:05 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una parola difficile
# 2026-04-12 10:38:06 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_difficult_word_41439d with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:06 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:06 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_difficult_word_41439d.mp3 (local cache enabled)
# 2026-04-12 10:38:06 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_difficult_word_41439d.mp3 (local cache enabled)
# 19: A fact about the world
# 2026-04-12 10:38:09 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un fatto sul mondo
# 2026-04-12 10:38:09 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_fact_about_the_world_ba49e6 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:09 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:09 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_fact_about_the_world_ba49e6.mp3 (local cache enabled)
# 2026-04-12 10:38:10 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_fact_about_the_world_ba49e6.mp3 (local cache enabled)
# 20: A football on the check-in desk
# 2026-04-12 10:38:13 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un pallone da calcio sul banco del check-in
# 2026-04-12 10:38:14 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_football_on_the_checkin_desk_8a48a0 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:14 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_football_on_the_checkin_desk_8a48a0.mp3 (local cache enabled)
# 2026-04-12 10:38:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_football_on_the_checkin_desk_8a48a0.mp3 (local cache enabled)
# 21: A free copy of the film
# 2026-04-12 10:38:17 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una copia gratuita del film
# 2026-04-12 10:38:17 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_free_copy_of_the_film_7efdda with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:17 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:17 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_free_copy_of_the_film_7efdda.mp3 (local cache enabled)
# 2026-04-12 10:38:18 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_free_copy_of_the_film_7efdda.mp3 (local cache enabled)
# 22: A full drink indeed!
# 2026-04-12 10:38:20 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un drink davvero abbondante!
# 2026-04-12 10:38:20 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_full_drink_indeed_595791 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:21 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:21 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_full_drink_indeed_595791.mp3 (local cache enabled)
# 2026-04-12 10:38:21 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_full_drink_indeed_595791.mp3 (local cache enabled)
# 23: A good example
# 2026-04-12 10:38:23 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un buon esempio
# 2026-04-12 10:38:24 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_good_example_1e2492 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:24 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:24 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_good_example_1e2492.mp3 (local cache enabled)
# 2026-04-12 10:38:24 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_good_example_1e2492.mp3 (local cache enabled)
# 24: A guy on the street
# 2026-04-12 10:38:26 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un ragazzo per strada
# 2026-04-12 10:38:27 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_guy_on_the_street_215858 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:27 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:27 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_guy_on_the_street_215858.mp3 (local cache enabled)
# 2026-04-12 10:38:27 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_guy_on_the_street_215858.mp3 (local cache enabled)
# 25: A high quality service
# 2026-04-12 10:38:30 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un servizio di alta qualità
# 2026-04-12 10:38:31 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_high_quality_service_44b1f5 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:31 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:31 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_high_quality_service_44b1f5.mp3 (local cache enabled)
# 2026-04-12 10:38:31 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_high_quality_service_44b1f5.mp3 (local cache enabled)
# 26: A high rate of interest
# 2026-04-12 10:38:33 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un tasso di interesse alto
# 2026-04-12 10:38:34 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_high_rate_of_interest_58ed09 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:34 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:34 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_high_rate_of_interest_58ed09.mp3 (local cache enabled)
# 2026-04-12 10:38:34 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_high_rate_of_interest_58ed09.mp3 (local cache enabled)
# 27: A horse on top of the well
# 2026-04-12 10:38:36 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un cavallo sopra il pozzo
# 2026-04-12 10:38:37 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_horse_on_top_of_the_well_286ff3 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:37 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:37 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_horse_on_top_of_the_well_286ff3.mp3 (local cache enabled)
# 2026-04-12 10:38:37 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_horse_on_top_of_the_well_286ff3.mp3 (local cache enabled)
# 28: A kind gesture
# 2026-04-12 10:38:40 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un gesto gentile
# 2026-04-12 10:38:40 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_kind_gesture_0ea4ec with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:40 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:40 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_kind_gesture_0ea4ec.mp3 (local cache enabled)
# 2026-04-12 10:38:40 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_kind_gesture_0ea4ec.mp3 (local cache enabled)
# 29: A Law degree is hard
# 2026-04-12 10:38:43 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una laurea in Giurisprudenza è difficile
# 2026-04-12 10:38:44 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_law_degree_is_hard_997b22 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:44 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:44 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_law_degree_is_hard_997b22.mp3 (local cache enabled)
# 2026-04-12 10:38:44 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_law_degree_is_hard_997b22.mp3 (local cache enabled)
# 30: A letter from the school
# 2026-04-12 10:38:46 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una lettera della scuola
# 2026-04-12 10:38:47 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_letter_from_the_school_21ab6a with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:47 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:47 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_letter_from_the_school_21ab6a.mp3 (local cache enabled)
# 2026-04-12 10:38:47 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_letter_from_the_school_21ab6a.mp3 (local cache enabled)
# 31: A light lunch
# 2026-04-12 10:38:49 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un pranzo leggero
# 2026-04-12 10:38:50 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_light_lunch_f1bb3d with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:50 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:50 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_light_lunch_f1bb3d.mp3 (local cache enabled)
# 2026-04-12 10:38:50 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_light_lunch_f1bb3d.mp3 (local cache enabled)
# 32: A list of choices
# 2026-04-12 10:38:53 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una lista di scelte
# 2026-04-12 10:38:54 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_list_of_choices_902b84 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:54 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:54 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_list_of_choices_902b84.mp3 (local cache enabled)
# 2026-04-12 10:38:54 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_list_of_choices_902b84.mp3 (local cache enabled)
# 33: A little too straight
# 2026-04-12 10:38:56 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: un po' troppo diretto
# 2026-04-12 10:38:57 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_little_too_straight_8947a5 with it-IT translation to Firestore and GCS
# 2026-04-12 10:38:57 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:38:57 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_little_too_straight_8947a5.mp3 (local cache enabled)
# 2026-04-12 10:38:57 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_little_too_straight_8947a5.mp3 (local cache enabled)
# 34: A local production centre
# 2026-04-12 10:38:59 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un centro di produzione locale
# 2026-04-12 10:39:00 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_local_production_centre_6d89c2 with it-IT translation to Firestore and GCS
# 2026-04-12 10:39:00 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:39:00 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_local_production_centre_6d89c2.mp3 (local cache enabled)
# 2026-04-12 10:39:00 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_local_production_centre_6d89c2.mp3 (local cache enabled)
# 35: A long sentence
# 2026-04-12 10:39:04 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Una frase lunga
# 2026-04-12 10:39:04 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_long_sentence_605cdc with it-IT translation to Firestore and GCS
# 2026-04-12 10:39:04 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:39:04 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_long_sentence_605cdc.mp3 (local cache enabled)
# 2026-04-12 10:39:05 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_long_sentence_605cdc.mp3 (local cache enabled)
# 36: A member of the club
# 2026-04-12 10:39:07 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un socio del club
# 2026-04-12 10:39:08 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_member_of_the_club_71d445 with it-IT translation to Firestore and GCS
# 2026-04-12 10:39:08 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:39:08 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_member_of_the_club_71d445.mp3 (local cache enabled)
# 2026-04-12 10:39:08 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_member_of_the_club_71d445.mp3 (local cache enabled)
# 37: A new housing development
# 2026-04-12 10:39:10 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un nuovo complesso residenziale
# 2026-04-12 10:39:11 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_new_housing_development_f9a3e8 with it-IT translation to Firestore and GCS
# 2026-04-12 10:39:11 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:39:11 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_new_housing_development_f9a3e8.mp3 (local cache enabled)
# 2026-04-12 10:39:11 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_new_housing_development_f9a3e8.mp3 (local cache enabled)
# 38: A penny for everybody
# 2026-04-12 10:39:13 - audio-language-trainer - INFO - phrase_model.py:344 - (y) Created translation for it-IT: Un centesimo per tutti
# 2026-04-12 10:39:14 - audio-language-trainer - INFO - phrase_model.py:374 - Uploading phrase a_penny_for_everybody_c92b52 with it-IT translation to Firestore and GCS
# 2026-04-12 10:39:14 - audio-language-trainer - INFO - phrase_model.py:1024 - Uploading all multimedia for it-IT translation
# 2026-04-12 10:39:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/normal to phrases/it-IT/audio/flashcard/normal/a_penny_for_everybody_c92b52.mp3 (local cache enabled)
# 2026-04-12 10:39:14 - audio-language-trainer - INFO - phrase_model.py:803 - Uploading audio: it-IT flashcard/slow to phrases/it-IT/audio/flashcard/slow/a_penny_for_everybody_c92b52.mp3 (local cache enabled)
# 39: A pretty blue flower

# %% [markdown]
# # Build several packs

# %%
deck_range = range(1, 16)
decks = [f"Pack{i:02d}" for i in deck_range]
print(TARGET_LANGUAGE.display_name())
target_language_tag = TARGET_LANGUAGE.to_tag()
language_name = TARGET_LANGUAGE.language_name()
print(decks)
# Out:
# Italian (Italy)
# ['Pack01', 'Pack02', 'Pack03', 'Pack04', 'Pack05', 'Pack06', 'Pack07', 'Pack08', 'Pack09', 'Pack10', 'Pack11', 'Pack12', 'Pack13', 'Pack14', 'Pack15']

# %%
for deck in decks:
    phrases = get_phrases_by_collection(COLLECTION, deck)
    

    # for p in phrases:
    #     p.translate(target_language=TARGET_LANGUAGE, refine=True)
    #     p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
    #     #p.generate_image()
    #     p.upload()
        
    phrases = sorted(phrases, key=lambda x: len(x.translations[str(TARGET_LANGUAGE)].text))

    create_anki_deck(
        phrases,
        source_language=SOURCE_LANGUAGE,
        target_language=TARGET_LANGUAGE,
        output_path=f"../outputs/decks/{target_language_tag}/{target_language_tag}-{COLLECTION}-{deck}.apkg",
        deck_name=f"FirePhrase - {language_name}::{collection_title}::{deck}",
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 11
#       2 phrases = get_phrases_by_collection(COLLECTION, deck)
#       5 # for p in phrases:
#       6 #     p.translate(target_language=TARGET_LANGUAGE, refine=True)
#       7 #     p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
#       8 #     #p.generate_image()
#       9 #     p.upload()
# ---> 11 phrases = sorted(phrases, key=lambda x: len(x.translations[str(TARGET_LANGUAGE)].text))
#      13 create_anki_deck(
#      14     phrases,
#      15     source_language=SOURCE_LANGUAGE,
#    (...)     18     deck_name=f"FirePhrase - {language_name}::{collection_title}::{deck}",
#      19 )
#
# Cell In[11], line 11, in <lambda>(x)
#       2 phrases = get_phrases_by_collection(COLLECTION, deck)
#       5 # for p in phrases:
#       6 #     p.translate(target_language=TARGET_LANGUAGE, refine=True)
#       7 #     p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
#       8 #     #p.generate_image()
#       9 #     p.upload()
# ---> 11 phrases = sorted(phrases, key=lambda x: len(x.translations[str(TARGET_LANGUAGE)].text))
#      13 create_anki_deck(
#      14     phrases,
#      15     source_language=SOURCE_LANGUAGE,
#    (...)     18     deck_name=f"FirePhrase - {language_name}::{collection_title}::{deck}",
#      19 )
#
# KeyError: 'it-IT'

# %%
phrases[0].translations.keys()
