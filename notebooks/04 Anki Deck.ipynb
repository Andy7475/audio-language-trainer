# %%
# %load_ext autoreload
# %autoreload 2

from setup_imports import *  # noqa: F401,F403
from langcodes import Language
from phrases.search import get_phrases_by_collection
from anki_tools import create_anki_deck
from convert import get_collection_title

COLLECTION = "LM1000"
DECK = "Pack01"
collection_title = get_collection_title(COLLECTION)

# %% [markdown]
# # Flash Card Creation

# %%
PHRASES = get_phrases_by_collection(COLLECTION, DECK)
print(len(PHRASES))
# Out:
# (y) Authenticated with Google Cloud project: swedish-course
# 72

# %%
TARGET_LANGUAGE = Language.get("nl-NL")
print(TARGET_LANGUAGE.display_name())
SOURCE_LANGUAGE = Language.get("sv-SE")
print(SOURCE_LANGUAGE.display_name())
# Out:
# Dutch (Netherlands)
# Swedish (Sweden)

# %%
for i, p in enumerate(PHRASES):
    print(f"{i}: {p.english}")
    p.translate(target_language=TARGET_LANGUAGE, refine=True, split_on_space=True)
    p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
    p.upload(TARGET_LANGUAGE)
# Out:
# 0: A difficult job
# (y) Google Translate API client initialized
# 2026-05-02 18:01:25 - audio-language-trainer - INFO - nlp.py:66 - _load_spacy_model: model 'nl_core_news_lg' not found locally, downloading…
# ✔ Download and installation successful
# You can now load the package via spacy.load('nl_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# 2026-05-02 18:02:18 - audio-language-trainer - INFO - nlp.py:83 - _load_spacy_model: loaded spaCy model 'nl_core_news_lg' for language 'nl'
# 2026-05-02 18:02:18 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een lastige klus - tokens: ['Een', 'lastige', 'klus']
# (y) Google Cloud Storage client initialized
# (y) Google Text-to-Speech API client initialized
# 2026-05-02 18:02:23 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_difficult_job_20ca23 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:23 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:23 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_difficult_job_20ca23.mp3 (local cache enabled)
# 2026-05-02 18:02:23 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_difficult_job_20ca23.mp3 (local cache enabled)
# 1: A difficult word
# 2026-05-02 18:02:25 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een moeilijk woord - tokens: ['Een', 'moeilijk', 'woord']
# 2026-05-02 18:02:26 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_difficult_word_41439d with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:26 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:26 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_difficult_word_41439d.mp3 (local cache enabled)
# 2026-05-02 18:02:26 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_difficult_word_41439d.mp3 (local cache enabled)
# 2: A fact about the world
# 2026-05-02 18:02:28 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een feit over de wereld - tokens: ['Een', 'feit', 'over', 'de', 'wereld']
# 2026-05-02 18:02:28 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_fact_about_the_world_ba49e6 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:28 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:29 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_fact_about_the_world_ba49e6.mp3 (local cache enabled)
# 2026-05-02 18:02:29 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_fact_about_the_world_ba49e6.mp3 (local cache enabled)
# 3: A little too straight
# 2026-05-02 18:02:31 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: een beetje te rechtdoorzee - tokens: ['een', 'beetje', 'te', 'rechtdoorzee']
# 2026-05-02 18:02:31 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_little_too_straight_8947a5 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:31 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:31 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_little_too_straight_8947a5.mp3 (local cache enabled)
# 2026-05-02 18:02:32 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_little_too_straight_8947a5.mp3 (local cache enabled)
# 4: A pretty blue flower
# 2026-05-02 18:02:33 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een mooie blauwe bloem - tokens: ['Een', 'mooie', 'blauwe', 'bloem']
# 2026-05-02 18:02:34 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_pretty_blue_flower_769e8e with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:34 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:34 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_pretty_blue_flower_769e8e.mp3 (local cache enabled)
# 2026-05-02 18:02:34 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_pretty_blue_flower_769e8e.mp3 (local cache enabled)
# 5: A serious medical condition
# 2026-05-02 18:02:36 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een ernstige medische aandoening - tokens: ['Een', 'ernstige', 'medische', 'aandoening']
# 2026-05-02 18:02:37 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase a_serious_medical_condition_c1a89b with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:37 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:37 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/a_serious_medical_condition_c1a89b.mp3 (local cache enabled)
# 2026-05-02 18:02:37 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/a_serious_medical_condition_c1a89b.mp3 (local cache enabled)
# 6: All of them together
# 2026-05-02 18:02:39 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Allemaal samen - tokens: ['Allemaal', 'samen']
# 2026-05-02 18:02:40 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase all_of_them_together_323881 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:40 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:40 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/all_of_them_together_323881.mp3 (local cache enabled)
# 2026-05-02 18:02:40 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/all_of_them_together_323881.mp3 (local cache enabled)
# 7: An officer at the college
# 2026-05-02 18:02:42 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een medewerker van de hogeschool - tokens: ['Een', 'medewerker', 'van', 'de', 'hogeschool']
# 2026-05-02 18:02:43 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase an_officer_at_the_college_7ae8f9 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:43 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:43 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/an_officer_at_the_college_7ae8f9.mp3 (local cache enabled)
# 2026-05-02 18:02:43 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/an_officer_at_the_college_7ae8f9.mp3 (local cache enabled)
# 8: Apparently she's single
# 2026-05-02 18:02:45 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Blijkbaar is ze single - tokens: ['Blijkbaar', 'is', 'ze', 'single']
# 2026-05-02 18:02:45 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase apparently_shes_single_1c829f with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:45 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:45 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/apparently_shes_single_1c829f.mp3 (local cache enabled)
# 2026-05-02 18:02:46 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/apparently_shes_single_1c829f.mp3 (local cache enabled)
# 9: Around an ordinary office
# 2026-05-02 18:02:48 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Rond een gewoon kantoor - tokens: ['Rond', 'een', 'gewoon', 'kantoor']
# 2026-05-02 18:02:48 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase around_an_ordinary_office_719ab5 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:48 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:48 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/around_an_ordinary_office_719ab5.mp3 (local cache enabled)
# 2026-05-02 18:02:49 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/around_an_ordinary_office_719ab5.mp3 (local cache enabled)
# 10: Ask a question
# 2026-05-02 18:02:50 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Stel een vraag - tokens: ['Stel', 'een', 'vraag']
# 2026-05-02 18:02:51 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase ask_a_question_3a533d with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:51 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:51 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/ask_a_question_3a533d.mp3 (local cache enabled)
# 2026-05-02 18:02:51 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/ask_a_question_3a533d.mp3 (local cache enabled)
# 11: Can you explain this?
# 2026-05-02 18:02:53 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Kun je dit uitleggen? - tokens: ['Kun', 'je', 'dit', 'uitleggen?']
# 2026-05-02 18:02:54 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase can_you_explain_this_4acf9d with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:54 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:54 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/can_you_explain_this_4acf9d.mp3 (local cache enabled)
# 2026-05-02 18:02:54 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/can_you_explain_this_4acf9d.mp3 (local cache enabled)
# 12: Certainly the right point
# 2026-05-02 18:02:56 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zeker het juiste punt - tokens: ['Zeker', 'het', 'juiste', 'punt']
# 2026-05-02 18:02:56 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase certainly_the_right_point_69820f with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:56 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:56 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/certainly_the_right_point_69820f.mp3 (local cache enabled)
# 2026-05-02 18:02:56 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/certainly_the_right_point_69820f.mp3 (local cache enabled)
# 13: Definitely the right information
# 2026-05-02 18:02:58 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zeker de juiste informatie - tokens: ['Zeker', 'de', 'juiste', 'informatie']
# 2026-05-02 18:02:59 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase definitely_the_right_information_82e525 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:02:59 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:02:59 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/definitely_the_right_information_82e525.mp3 (local cache enabled)
# 2026-05-02 18:02:59 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/definitely_the_right_information_82e525.mp3 (local cache enabled)
# 14: For a little while
# 2026-05-02 18:03:01 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Een tijdje - tokens: ['Een', 'tijdje']
# 2026-05-02 18:03:02 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase for_a_little_while_f3e23d with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:02 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/for_a_little_while_f3e23d.mp3 (local cache enabled)
# 2026-05-02 18:03:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/for_a_little_while_f3e23d.mp3 (local cache enabled)
# 15: Half of the time
# 2026-05-02 18:03:04 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: De helft van de tijd - tokens: ['De', 'helft', 'van', 'de', 'tijd']
# 2026-05-02 18:03:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase half_of_the_time_4b2bfe with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:05 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/half_of_the_time_4b2bfe.mp3 (local cache enabled)
# 2026-05-02 18:03:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/half_of_the_time_4b2bfe.mp3 (local cache enabled)
# 16: He runs a business
# 2026-05-02 18:03:07 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Hij heeft een bedrijf - tokens: ['Hij', 'heeft', 'een', 'bedrijf']
# 2026-05-02 18:03:08 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase he_runs_a_business_93ea89 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:08 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:08 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/he_runs_a_business_93ea89.mp3 (local cache enabled)
# 2026-05-02 18:03:08 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/he_runs_a_business_93ea89.mp3 (local cache enabled)
# 17: I ask for directions
# 2026-05-02 18:03:10 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik vraag de weg - tokens: ['Ik', 'vraag', 'de', 'weg']
# 2026-05-02 18:03:10 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_ask_for_directions_aa3877 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:10 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:10 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_ask_for_directions_aa3877.mp3 (local cache enabled)
# 2026-05-02 18:03:10 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_ask_for_directions_aa3877.mp3 (local cache enabled)
# 18: I explained my decision
# 2026-05-02 18:03:12 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik heb mijn beslissing uitgelegd - tokens: ['Ik', 'heb', 'mijn', 'beslissing', 'uitgelegd']
# 2026-05-02 18:03:13 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_explained_my_decision_ccf3d1 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:13 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:13 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_explained_my_decision_ccf3d1.mp3 (local cache enabled)
# 2026-05-02 18:03:13 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_explained_my_decision_ccf3d1.mp3 (local cache enabled)
# 19: I follow that channel
# 2026-05-02 18:03:15 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik volg dat kanaal - tokens: ['Ik', 'volg', 'dat', 'kanaal']
# 2026-05-02 18:03:16 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_follow_that_channel_cb7ca2 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:16 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_follow_that_channel_cb7ca2.mp3 (local cache enabled)
# 2026-05-02 18:03:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_follow_that_channel_cb7ca2.mp3 (local cache enabled)
# 20: I follow the rules
# 2026-05-02 18:03:18 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik volg de regels - tokens: ['Ik', 'volg', 'de', 'regels']
# 2026-05-02 18:03:18 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_follow_the_rules_952c28 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:18 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:18 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_follow_the_rules_952c28.mp3 (local cache enabled)
# 2026-05-02 18:03:18 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_follow_the_rules_952c28.mp3 (local cache enabled)
# 21: I open the door
# 2026-05-02 18:03:20 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik doe de deur open - tokens: ['Ik', 'doe', 'de', 'deur', 'open']
# 2026-05-02 18:03:21 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_open_the_door_b9a129 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:21 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:21 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_open_the_door_b9a129.mp3 (local cache enabled)
# 2026-05-02 18:03:21 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_open_the_door_b9a129.mp3 (local cache enabled)
# 22: I realise my mistake
# 2026-05-02 18:03:23 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik zie mijn fout in - tokens: ['Ik', 'zie', 'mijn', 'fout', 'in']
# 2026-05-02 18:03:23 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_realise_my_mistake_1e3479 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:24 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:24 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_realise_my_mistake_1e3479.mp3 (local cache enabled)
# 2026-05-02 18:03:24 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_realise_my_mistake_1e3479.mp3 (local cache enabled)
# 23: I run every morning
# 2026-05-02 18:03:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik ga elke ochtend hardlopen - tokens: ['Ik', 'ga', 'elke', 'ochtend', 'hardlopen']
# 2026-05-02 18:03:26 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_run_every_morning_983cd0 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:26 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:26 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_run_every_morning_983cd0.mp3 (local cache enabled)
# 2026-05-02 18:03:26 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_run_every_morning_983cd0.mp3 (local cache enabled)
# 24: I wore a hat
# 2026-05-02 18:03:28 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik had een hoed op - tokens: ['Ik', 'had', 'een', 'hoed', 'op']
# 2026-05-02 18:03:30 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase i_wore_a_hat_bbdd03 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:30 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/i_wore_a_hat_bbdd03.mp3 (local cache enabled)
# 2026-05-02 18:03:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/i_wore_a_hat_bbdd03.mp3 (local cache enabled)
# 25: Is there anybody in the room?
# 2026-05-02 18:03:32 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Is er iemand in de kamer? - tokens: ['Is', 'er', 'iemand', 'in', 'de', 'kamer?']
# 2026-05-02 18:03:32 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase is_there_anybody_in_the_room_f40d8a with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:32 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:32 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/is_there_anybody_in_the_room_f40d8a.mp3 (local cache enabled)
# 2026-05-02 18:03:33 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/is_there_anybody_in_the_room_f40d8a.mp3 (local cache enabled)
# 26: It figures prominently
# 2026-05-02 18:03:34 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het speelt een prominente rol - tokens: ['Het', 'speelt', 'een', 'prominente', 'rol']
# 2026-05-02 18:03:35 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase it_figures_prominently_67f1cf with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:35 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:35 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/it_figures_prominently_67f1cf.mp3 (local cache enabled)
# 2026-05-02 18:03:35 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/it_figures_prominently_67f1cf.mp3 (local cache enabled)
# 27: It moves slowly
# 2026-05-02 18:03:37 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het beweegt langzaam - tokens: ['Het', 'beweegt', 'langzaam']
# 2026-05-02 18:03:37 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase it_moves_slowly_cec6a3 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:38 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:38 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/it_moves_slowly_cec6a3.mp3 (local cache enabled)
# 2026-05-02 18:03:38 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/it_moves_slowly_cec6a3.mp3 (local cache enabled)
# 28: It was a large order
# 2026-05-02 18:03:39 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het was een grote bestelling - tokens: ['Het', 'was', 'een', 'grote', 'bestelling']
# 2026-05-02 18:03:40 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase it_was_a_large_order_9532a0 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:40 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:40 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/it_was_a_large_order_9532a0.mp3 (local cache enabled)
# 2026-05-02 18:03:40 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/it_was_a_large_order_9532a0.mp3 (local cache enabled)
# 29: It's about his trust issues
# 2026-05-02 18:03:42 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het gaat om zijn vertrouwensproblemen - tokens: ['Het', 'gaat', 'om', 'zijn', 'vertrouwensproblemen']
# 2026-05-02 18:03:42 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase its_about_his_trust_issues_fb574c with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:43 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:43 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/its_about_his_trust_issues_fb574c.mp3 (local cache enabled)
# 2026-05-02 18:03:43 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/its_about_his_trust_issues_fb574c.mp3 (local cache enabled)
# 30: Less sugar in my coffee
# 2026-05-02 18:03:45 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Minder suiker in mijn koffie - tokens: ['Minder', 'suiker', 'in', 'mijn', 'koffie']
# 2026-05-02 18:03:45 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase less_sugar_in_my_coffee_6d5a52 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:45 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:45 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/less_sugar_in_my_coffee_6d5a52.mp3 (local cache enabled)
# 2026-05-02 18:03:46 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/less_sugar_in_my_coffee_6d5a52.mp3 (local cache enabled)
# 31: May I ask something?
# 2026-05-02 18:03:47 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Mag ik iets vragen? - tokens: ['Mag', 'ik', 'iets', 'vragen?']
# 2026-05-02 18:03:48 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase may_i_ask_something_072df4 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:48 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:48 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/may_i_ask_something_072df4.mp3 (local cache enabled)
# 2026-05-02 18:03:48 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/may_i_ask_something_072df4.mp3 (local cache enabled)
# 32: My father's old watch
# 2026-05-02 18:03:50 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Mijn vaders oude horloge - tokens: ['Mijn', 'vaders', 'oude', 'horloge']
# 2026-05-02 18:03:50 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase my_fathers_old_watch_c6a0ba with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:50 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:50 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/my_fathers_old_watch_c6a0ba.mp3 (local cache enabled)
# 2026-05-02 18:03:51 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/my_fathers_old_watch_c6a0ba.mp3 (local cache enabled)
# 33: My lovely husband
# 2026-05-02 18:03:53 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Mijn lieve man - tokens: ['Mijn', 'lieve', 'man']
# 2026-05-02 18:03:53 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase my_lovely_husband_0103c7 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:53 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:53 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/my_lovely_husband_0103c7.mp3 (local cache enabled)
# 2026-05-02 18:03:53 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/my_lovely_husband_0103c7.mp3 (local cache enabled)
# 34: On the open water
# 2026-05-02 18:03:55 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Op het open water - tokens: ['Op', 'het', 'open', 'water']
# 2026-05-02 18:03:56 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase on_the_open_water_516d3a with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:56 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:56 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/on_the_open_water_516d3a.mp3 (local cache enabled)
# 2026-05-02 18:03:56 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/on_the_open_water_516d3a.mp3 (local cache enabled)
# 35: Open your book please
# 2026-05-02 18:03:58 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Open je boek alsjeblieft - tokens: ['Open', 'je', 'boek', 'alsjeblieft']
# 2026-05-02 18:03:59 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase open_your_book_please_feae3d with nl-NL translation to Firestore and GCS
# 2026-05-02 18:03:59 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:03:59 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/open_your_book_please_feae3d.mp3 (local cache enabled)
# 2026-05-02 18:03:59 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/open_your_book_please_feae3d.mp3 (local cache enabled)
# 36: Our budget is $1000
# 2026-05-02 18:04:01 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ons budget is 1000 dollar - tokens: ['Ons', 'budget', 'is', '1000', 'dollar']
# 2026-05-02 18:04:02 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase our_budget_is_1000_488d79 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:02 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/our_budget_is_1000_488d79.mp3 (local cache enabled)
# 2026-05-02 18:04:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/our_budget_is_1000_488d79.mp3 (local cache enabled)
# 37: Outside in the water
# 2026-05-02 18:04:04 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Buiten in het water - tokens: ['Buiten', 'in', 'het', 'water']
# 2026-05-02 18:04:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase outside_in_the_water_a0e6af with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:05 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/outside_in_the_water_a0e6af.mp3 (local cache enabled)
# 2026-05-02 18:04:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/outside_in_the_water_a0e6af.mp3 (local cache enabled)
# 38: Please explain your reasoning
# 2026-05-02 18:04:07 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Leg je redenering uit - tokens: ['Leg', 'je', 'redenering', 'uit']
# 2026-05-02 18:04:07 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase please_explain_your_reasoning_98582e with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:07 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:07 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/please_explain_your_reasoning_98582e.mp3 (local cache enabled)
# 2026-05-02 18:04:08 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/please_explain_your_reasoning_98582e.mp3 (local cache enabled)
# 39: Please follow the path
# 2026-05-02 18:04:10 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Volg het pad alsjeblieft - tokens: ['Volg', 'het', 'pad', 'alsjeblieft']
# 2026-05-02 18:04:10 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase please_follow_the_path_af166e with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:10 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:10 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/please_follow_the_path_af166e.mp3 (local cache enabled)
# 2026-05-02 18:04:11 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/please_follow_the_path_af166e.mp3 (local cache enabled)
# 40: Please move over
# 2026-05-02 18:04:13 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ga alsjeblieft opzij - tokens: ['Ga', 'alsjeblieft', 'opzij']
# 2026-05-02 18:04:13 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase please_move_over_c9ea26 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:13 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:13 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/please_move_over_c9ea26.mp3 (local cache enabled)
# 2026-05-02 18:04:14 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/please_move_over_c9ea26.mp3 (local cache enabled)
# 41: Quite a beautiful sunset
# 2026-05-02 18:04:15 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Best een mooie zonsondergang - tokens: ['Best', 'een', 'mooie', 'zonsondergang']
# 2026-05-02 18:04:16 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase quite_a_beautiful_sunset_89d101 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:16 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/quite_a_beautiful_sunset_89d101.mp3 (local cache enabled)
# 2026-05-02 18:04:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/quite_a_beautiful_sunset_89d101.mp3 (local cache enabled)
# 42: Shall we open it
# 2026-05-02 18:04:18 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zullen we het openmaken? - tokens: ['Zullen', 'we', 'het', 'openmaken?']
# 2026-05-02 18:04:19 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase shall_we_open_it_731166 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:19 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:19 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/shall_we_open_it_731166.mp3 (local cache enabled)
# 2026-05-02 18:04:19 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/shall_we_open_it_731166.mp3 (local cache enabled)
# 43: She asked for help
# 2026-05-02 18:04:21 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze vroeg om hulp - tokens: ['Ze', 'vroeg', 'om', 'hulp']
# 2026-05-02 18:04:22 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_asked_for_help_e578c8 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:22 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:22 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_asked_for_help_e578c8.mp3 (local cache enabled)
# 2026-05-02 18:04:22 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_asked_for_help_e578c8.mp3 (local cache enabled)
# 44: She explains the concept
# 2026-05-02 18:04:24 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze legt het concept uit - tokens: ['Ze', 'legt', 'het', 'concept', 'uit']
# 2026-05-02 18:04:24 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_explains_the_concept_1e076c with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:24 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:24 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_explains_the_concept_1e076c.mp3 (local cache enabled)
# 2026-05-02 18:04:25 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_explains_the_concept_1e076c.mp3 (local cache enabled)
# 45: She figured it out
# 2026-05-02 18:04:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze kwam erachter - tokens: ['Ze', 'kwam', 'erachter']
# 2026-05-02 18:04:27 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_figured_it_out_0c3864 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:27 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:27 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_figured_it_out_0c3864.mp3 (local cache enabled)
# 2026-05-02 18:04:27 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_figured_it_out_0c3864.mp3 (local cache enabled)
# 46: She followed the instructions
# 2026-05-02 18:04:29 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze volgde de instructies op - tokens: ['Ze', 'volgde', 'de', 'instructies', 'op']
# 2026-05-02 18:04:30 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_followed_the_instructions_afa5c9 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:30 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_followed_the_instructions_afa5c9.mp3 (local cache enabled)
# 2026-05-02 18:04:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_followed_the_instructions_afa5c9.mp3 (local cache enabled)
# 47: She opened the window
# 2026-05-02 18:04:32 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze deed het raam open - tokens: ['Ze', 'deed', 'het', 'raam', 'open']
# 2026-05-02 18:04:32 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_opened_the_window_0c5f0c with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:33 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:33 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_opened_the_window_0c5f0c.mp3 (local cache enabled)
# 2026-05-02 18:04:33 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_opened_the_window_0c5f0c.mp3 (local cache enabled)
# 48: She ran yesterday
# 2026-05-02 18:04:35 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze rende gisteren - tokens: ['Ze', 'rende', 'gisteren']
# 2026-05-02 18:04:35 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_ran_yesterday_cfc7e7 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:35 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:35 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_ran_yesterday_cfc7e7.mp3 (local cache enabled)
# 2026-05-02 18:04:35 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_ran_yesterday_cfc7e7.mp3 (local cache enabled)
# 49: She realised the truth
# 2026-05-02 18:04:37 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze kwam erachter wat de waarheid was - tokens: ['Ze', 'kwam', 'erachter', 'wat', 'de', 'waarheid', 'was']
# 2026-05-02 18:04:38 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_realised_the_truth_3cd5a1 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:38 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:38 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_realised_the_truth_3cd5a1.mp3 (local cache enabled)
# 2026-05-02 18:04:38 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_realised_the_truth_3cd5a1.mp3 (local cache enabled)
# 50: She wears blue jeans
# 2026-05-02 18:04:40 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze draagt een blauwe spijkerbroek - tokens: ['Ze', 'draagt', 'een', 'blauwe', 'spijkerbroek']
# 2026-05-02 18:04:41 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_wears_blue_jeans_f90020 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:41 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:41 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/she_wears_blue_jeans_f90020.mp3 (local cache enabled)
# 2026-05-02 18:04:41 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/she_wears_blue_jeans_f90020.mp3 (local cache enabled)
# 51: She wins every time
# 2026-05-02 18:04:43 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze wint elke keer - tokens: ['Ze', 'wint', 'elke', 'keer']
# 2026-05-02 18:04:44 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase she_wins_every_time_bafd87 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:44 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# ...
# 2026-05-02 18:04:51 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/the_human_body_d4d1a9.mp3 (local cache enabled)
# 2026-05-02 18:04:52 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/the_human_body_d4d1a9.mp3 (local cache enabled)
# 55: The lecture follows dinner
# 2026-05-02 18:04:53 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: De lezing volgt het diner - tokens: ['De', 'lezing', 'volgt', 'het', 'diner']
# 2026-05-02 18:04:54 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase the_lecture_follows_dinner_c99418 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:54 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:54 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/the_lecture_follows_dinner_c99418.mp3 (local cache enabled)
# 2026-05-02 18:04:54 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/the_lecture_follows_dinner_c99418.mp3 (local cache enabled)
# 56: The store opens tomorrow
# 2026-05-02 18:04:56 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: De winkel gaat morgen open - tokens: ['De', 'winkel', 'gaat', 'morgen', 'open']
# 2026-05-02 18:04:56 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase the_store_opens_tomorrow_aa8013 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:56 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:57 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/the_store_opens_tomorrow_aa8013.mp3 (local cache enabled)
# 2026-05-02 18:04:57 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/the_store_opens_tomorrow_aa8013.mp3 (local cache enabled)
# 57: The water is running
# 2026-05-02 18:04:59 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het water loopt - tokens: ['Het', 'water', 'loopt']
# 2026-05-02 18:04:59 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase the_water_is_running_4f7532 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:04:59 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:04:59 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/the_water_is_running_4f7532.mp3 (local cache enabled)
# 2026-05-02 18:05:00 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/the_water_is_running_4f7532.mp3 (local cache enabled)
# 58: There are people behind the office
# 2026-05-02 18:05:01 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Er zijn mensen achter het kantoor - tokens: ['Er', 'zijn', 'mensen', 'achter', 'het', 'kantoor']
# 2026-05-02 18:05:02 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase there_are_people_behind_the_office_c7a139 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:02 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/there_are_people_behind_the_office_c7a139.mp3 (local cache enabled)
# 2026-05-02 18:05:02 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/there_are_people_behind_the_office_c7a139.mp3 (local cache enabled)
# 59: They moved to Paris
# 2026-05-02 18:05:04 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ze zijn naar Parijs verhuisd - tokens: ['Ze', 'zijn', 'naar', 'Parijs', 'verhuisd']
# 2026-05-02 18:05:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase they_moved_to_paris_509063 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:05 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/they_moved_to_paris_509063.mp3 (local cache enabled)
# 2026-05-02 18:05:05 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/they_moved_to_paris_509063.mp3 (local cache enabled)
# 60: Two equal parts
# 2026-05-02 18:05:07 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Twee gelijke delen - tokens: ['Twee', 'gelijke', 'delen']
# 2026-05-02 18:05:07 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase two_equal_parts_6fcadf with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:07 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:07 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/two_equal_parts_6fcadf.mp3 (local cache enabled)
# 2026-05-02 18:05:08 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/two_equal_parts_6fcadf.mp3 (local cache enabled)
# 61: We have no trust
# 2026-05-02 18:05:10 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: We hebben geen vertrouwen - tokens: ['We', 'hebben', 'geen', 'vertrouwen']
# 2026-05-02 18:05:11 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase we_have_no_trust_6a7650 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:11 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:11 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/we_have_no_trust_6a7650.mp3 (local cache enabled)
# 2026-05-02 18:05:11 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/we_have_no_trust_6a7650.mp3 (local cache enabled)
# 62: We will move soon
# 2026-05-02 18:05:13 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: We gaan binnenkort verhuizen. - tokens: ['We', 'gaan', 'binnenkort', 'verhuizen.']
# 2026-05-02 18:05:13 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase we_will_move_soon_7e382b with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:13 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:13 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/we_will_move_soon_7e382b.mp3 (local cache enabled)
# 2026-05-02 18:05:14 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/we_will_move_soon_7e382b.mp3 (local cache enabled)
# 63: We won the game
# 2026-05-02 18:05:15 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: We hebben de wedstrijd gewonnen - tokens: ['We', 'hebben', 'de', 'wedstrijd', 'gewonnen']
# 2026-05-02 18:05:16 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase we_won_the_game_3befb7 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:16 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/we_won_the_game_3befb7.mp3 (local cache enabled)
# 2026-05-02 18:05:16 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/we_won_the_game_3befb7.mp3 (local cache enabled)
# 64: When will they realise?
# 2026-05-02 18:05:18 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Wanneer gaan ze het doorhebben? - tokens: ['Wanneer', 'gaan', 'ze', 'het', 'doorhebben?']
# 2026-05-02 18:05:19 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase when_will_they_realise_2ffd97 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:19 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:19 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/when_will_they_realise_2ffd97.mp3 (local cache enabled)
# 2026-05-02 18:05:19 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/when_will_they_realise_2ffd97.mp3 (local cache enabled)
# 65: Will they win tomorrow?
# 2026-05-02 18:05:21 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Winnen ze morgen? - tokens: ['Winnen', 'ze', 'morgen?']
# 2026-05-02 18:05:22 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_they_win_tomorrow_5d7858 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:22 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:22 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_they_win_tomorrow_5d7858.mp3 (local cache enabled)
# 2026-05-02 18:05:22 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_they_win_tomorrow_5d7858.mp3 (local cache enabled)
# 66: Will you ask him?
# 2026-05-02 18:05:24 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ga je het hem vragen? - tokens: ['Ga', 'je', 'het', 'hem', 'vragen?']
# 2026-05-02 18:05:25 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_you_ask_him_b39108 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:25 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:25 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_you_ask_him_b39108.mp3 (local cache enabled)
# 2026-05-02 18:05:25 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_you_ask_him_b39108.mp3 (local cache enabled)
# 67: Will you follow me?
# 2026-05-02 18:05:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Volg je me? - tokens: ['Volg', 'je', 'me?']
# 2026-05-02 18:05:27 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_you_follow_me_b95c99 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:27 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:27 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_you_follow_me_b95c99.mp3 (local cache enabled)
# 2026-05-02 18:05:27 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_you_follow_me_b95c99.mp3 (local cache enabled)
# 68: Will you open it?
# 2026-05-02 18:05:29 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Wil je het openmaken? - tokens: ['Wil', 'je', 'het', 'openmaken?']
# 2026-05-02 18:05:30 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_you_open_it_fc908c with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:30 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_you_open_it_fc908c.mp3 (local cache enabled)
# 2026-05-02 18:05:30 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_you_open_it_fc908c.mp3 (local cache enabled)
# 69: Will you run tomorrow?
# 2026-05-02 18:05:33 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ga je morgen hardlopen? - tokens: ['Ga', 'je', 'morgen', 'hardlopen?']
# 2026-05-02 18:05:33 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_you_run_tomorrow_526c27 with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:33 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:33 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_you_run_tomorrow_526c27.mp3 (local cache enabled)
# 2026-05-02 18:05:34 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_you_run_tomorrow_526c27.mp3 (local cache enabled)
# 70: Will you wear this?
# 2026-05-02 18:05:36 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ga je dit aan doen? - tokens: ['Ga', 'je', 'dit', 'aan', 'doen?']
# 2026-05-02 18:05:36 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase will_you_wear_this_c5b52c with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:36 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:36 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/will_you_wear_this_c5b52c.mp3 (local cache enabled)
# 2026-05-02 18:05:37 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/will_you_wear_this_c5b52c.mp3 (local cache enabled)
# 71: You and your friend
# 2026-05-02 18:05:38 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Jij en je vriend - tokens: ['Jij', 'en', 'je', 'vriend']
# 2026-05-02 18:05:39 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase you_and_your_friend_ff140e with nl-NL translation to Firestore and GCS
# 2026-05-02 18:05:39 - audio-language-trainer - INFO - phrase_model.py:1048 - Uploading all multimedia for nl-NL translation
# 2026-05-02 18:05:39 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/normal to phrases/nl-NL/audio/flashcard/normal/you_and_your_friend_ff140e.mp3 (local cache enabled)
# 2026-05-02 18:05:39 - audio-language-trainer - INFO - phrase_model.py:816 - Uploading audio: nl-NL flashcard/slow to phrases/nl-NL/audio/flashcard/slow/you_and_your_friend_ff140e.mp3 (local cache enabled)

# %% [markdown]
# # Build several packs

# %%
deck_range = range(1, 2)
decks = [f"Pack{i:02d}" for i in deck_range]
print(TARGET_LANGUAGE.display_name())
target_language_tag = TARGET_LANGUAGE.to_tag()
language_name = TARGET_LANGUAGE.language_name()
print(decks)
# Out:
# Dutch (Netherlands)
# ['Pack01']

# %%
for deck in decks:
    phrases = get_phrases_by_collection(COLLECTION, deck)
    

    # for p in phrases:
    #     p.translate(target_language=TARGET_LANGUAGE, refine=True)
    #     p.generate_audio("flashcard", TARGET_LANGUAGE, split_on_space=True)
    #     #p.generate_image()
    #     p.upload()
        
    phrases = sorted(phrases, key=lambda x: len(x.translations[str(TARGET_LANGUAGE)].text))

    create_anki_deck(
        phrases,
        source_language=SOURCE_LANGUAGE,
        target_language=TARGET_LANGUAGE,
        output_path=f"../outputs/decks/{target_language_tag}/{target_language_tag}-{COLLECTION}-{deck}.apkg",
        deck_name=f"FirePhrase - {language_name}::{collection_title}::{deck}",
    )
# Out:
# 2026-05-02 18:12:01 - audio-language-trainer - INFO - anki_tools.py:349 - Creating Anki deck: FirePhrase - Dutch::Stage 1::Pack01
# 2026-05-02 18:12:01 - audio-language-trainer - INFO - anki_tools.py:350 - Source language: sv-SE
# 2026-05-02 18:12:01 - audio-language-trainer - INFO - anki_tools.py:351 - Target language: nl-NL
# 2026-05-02 18:12:01 - audio-language-trainer - INFO - anki_tools.py:352 - Processing 72 phrases...
# Creating notes:   0%|          | 0/72 [00:00<?, ?it/s]
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase for_a_little_while_f3e23d - nl-NL translation only
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/for_a_little_while_f3e23d.mp3 (with local cache)
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/for_a_little_while_f3e23d.mp3 (with local cache)
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/for_a_little_while_f3e23d.png (with local cache)
# Creating notes:   1%|▏         | 1/72 [00:01<01:13,  1.03s/it]
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase the_day_before_yesterday_ffa4b4 - nl-NL translation only
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/the_day_before_yesterday_ffa4b4.mp3 (with local cache)
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/the_day_before_yesterday_ffa4b4.mp3 (with local cache)
# 2026-05-02 18:12:02 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/the_day_before_yesterday_ffa4b4.png (with local cache)
# Creating notes:   3%|▎         | 2/72 [00:01<00:44,  1.57it/s]
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_you_follow_me_b95c99 - nl-NL translation only
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_you_follow_me_b95c99.mp3 (with local cache)
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_you_follow_me_b95c99.mp3 (with local cache)
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_you_follow_me_b95c99.png (with local cache)
# Creating notes:   4%|▍         | 3/72 [00:01<00:33,  2.06it/s]
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase all_of_them_together_323881 - nl-NL translation only
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/all_of_them_together_323881.mp3 (with local cache)
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/all_of_them_together_323881.mp3 (with local cache)
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/all_of_them_together_323881.png (with local cache)
# Creating notes:   6%|▌         | 4/72 [00:02<00:28,  2.35it/s]
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase ask_a_question_3a533d - nl-NL translation only
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/ask_a_question_3a533d.mp3 (with local cache)
# 2026-05-02 18:12:03 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/ask_a_question_3a533d.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/ask_a_question_3a533d.png (with local cache)
# Creating notes:   7%|▋         | 5/72 [00:02<00:27,  2.44it/s]
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase my_lovely_husband_0103c7 - nl-NL translation only
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/my_lovely_husband_0103c7.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/my_lovely_husband_0103c7.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/my_lovely_husband_0103c7.png (with local cache)
# Creating notes:   8%|▊         | 6/72 [00:02<00:25,  2.57it/s]
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_ask_for_directions_aa3877 - nl-NL translation only
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_ask_for_directions_aa3877.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_ask_for_directions_aa3877.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_ask_for_directions_aa3877.png (with local cache)
# Creating notes:  10%|▉         | 7/72 [00:03<00:23,  2.71it/s]
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase the_water_is_running_4f7532 - nl-NL translation only
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/the_water_is_running_4f7532.mp3 (with local cache)
# 2026-05-02 18:12:04 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/the_water_is_running_4f7532.mp3 (with local cache)
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/the_water_is_running_4f7532.png (with local cache)
# Creating notes:  11%|█         | 8/72 [00:03<00:23,  2.70it/s]
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase a_difficult_job_20ca23 - nl-NL translation only
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/a_difficult_job_20ca23.mp3 (with local cache)
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/a_difficult_job_20ca23.mp3 (with local cache)
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/a_difficult_job_20ca23.png (with local cache)
# Creating notes:  12%|█▎        | 9/72 [00:03<00:22,  2.77it/s]
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_asked_for_help_e578c8 - nl-NL translation only
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_asked_for_help_e578c8.mp3 (with local cache)
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_asked_for_help_e578c8.mp3 (with local cache)
# 2026-05-02 18:12:05 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_asked_for_help_e578c8.png (with local cache)
# Creating notes:  14%|█▍        | 10/72 [00:04<00:23,  2.68it/s]
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_figured_it_out_0c3864 - nl-NL translation only
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_figured_it_out_0c3864.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_figured_it_out_0c3864.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_figured_it_out_0c3864.png (with local cache)
# Creating notes:  15%|█▌        | 11/72 [00:04<00:22,  2.68it/s]
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase you_and_your_friend_ff140e - nl-NL translation only
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/you_and_your_friend_ff140e.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/you_and_your_friend_ff140e.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/you_and_your_friend_ff140e.png (with local cache)
# Creating notes:  17%|█▋        | 12/72 [00:04<00:21,  2.74it/s]
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_follow_the_rules_952c28 - nl-NL translation only
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_follow_the_rules_952c28.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_follow_the_rules_952c28.mp3 (with local cache)
# 2026-05-02 18:12:06 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_follow_the_rules_952c28.png (with local cache)
# Creating notes:  18%|█▊        | 13/72 [00:05<00:21,  2.78it/s]
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase on_the_open_water_516d3a - nl-NL translation only
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/on_the_open_water_516d3a.mp3 (with local cache)
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/on_the_open_water_516d3a.mp3 (with local cache)
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/on_the_open_water_516d3a.png (with local cache)
# Creating notes:  19%|█▉        | 14/72 [00:05<00:21,  2.69it/s]
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_ran_yesterday_cfc7e7 - nl-NL translation only
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_ran_yesterday_cfc7e7.mp3 (with local cache)
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_ran_yesterday_cfc7e7.mp3 (with local cache)
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_ran_yesterday_cfc7e7.png (with local cache)
# Creating notes:  21%|██        | 15/72 [00:06<00:21,  2.67it/s]
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_wins_every_time_bafd87 - nl-NL translation only
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_wins_every_time_bafd87.mp3 (with local cache)
# 2026-05-02 18:12:07 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_wins_every_time_bafd87.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_wins_every_time_bafd87.png (with local cache)
# Creating notes:  22%|██▏       | 16/72 [00:06<00:20,  2.69it/s]
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_they_win_tomorrow_5d7858 - nl-NL translation only
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_they_win_tomorrow_5d7858.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_they_win_tomorrow_5d7858.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_they_win_tomorrow_5d7858.png (with local cache)
# Creating notes:  24%|██▎       | 17/72 [00:06<00:19,  2.80it/s]
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase a_difficult_word_41439d - nl-NL translation only
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/a_difficult_word_41439d.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/a_difficult_word_41439d.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/a_difficult_word_41439d.png (with local cache)
# Creating notes:  25%|██▌       | 18/72 [00:07<00:19,  2.83it/s]
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_follow_that_channel_cb7ca2 - nl-NL translation only
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_follow_that_channel_cb7ca2.mp3 (with local cache)
# 2026-05-02 18:12:08 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_follow_that_channel_cb7ca2.mp3 (with local cache)
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_follow_that_channel_cb7ca2.png (with local cache)
# Creating notes:  26%|██▋       | 19/72 [00:07<00:18,  2.93it/s]
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_wore_a_hat_bbdd03 - nl-NL translation only
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_wore_a_hat_bbdd03.mp3 (with local cache)
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_wore_a_hat_bbdd03.mp3 (with local cache)
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_wore_a_hat_bbdd03.png (with local cache)
# Creating notes:  28%|██▊       | 20/72 [00:07<00:18,  2.87it/s]
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase two_equal_parts_6fcadf - nl-NL translation only
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/two_equal_parts_6fcadf.mp3 (with local cache)
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/two_equal_parts_6fcadf.mp3 (with local cache)
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/two_equal_parts_6fcadf.png (with local cache)
# Creating notes:  29%|██▉       | 21/72 [00:08<00:18,  2.77it/s]
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_open_the_door_b9a129 - nl-NL translation only
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:09 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_open_the_door_b9a129.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_open_the_door_b9a129.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_open_the_door_b9a129.png (with local cache)
# Creating notes:  31%|███       | 22/72 [00:08<00:17,  2.83it/s]
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_realise_my_mistake_1e3479 - nl-NL translation only
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_realise_my_mistake_1e3479.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_realise_my_mistake_1e3479.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_realise_my_mistake_1e3479.png (with local cache)
# Creating notes:  32%|███▏      | 23/72 [00:08<00:17,  2.84it/s]
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase may_i_ask_something_072df4 - nl-NL translation only
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/may_i_ask_something_072df4.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/may_i_ask_something_072df4.mp3 (with local cache)
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/may_i_ask_something_072df4.png (with local cache)
# Creating notes:  33%|███▎      | 24/72 [00:09<00:16,  2.95it/s]
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase outside_in_the_water_a0e6af - nl-NL translation only
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:10 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/outside_in_the_water_a0e6af.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/outside_in_the_water_a0e6af.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/outside_in_the_water_a0e6af.png (with local cache)
# Creating notes:  35%|███▍      | 25/72 [00:09<00:15,  3.12it/s]
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_you_wear_this_c5b52c - nl-NL translation only
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_you_wear_this_c5b52c.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_you_wear_this_c5b52c.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_you_wear_this_c5b52c.png (with local cache)
# Creating notes:  36%|███▌      | 26/72 [00:09<00:15,  2.94it/s]
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase half_of_the_time_4b2bfe - nl-NL translation only
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/half_of_the_time_4b2bfe.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/half_of_the_time_4b2bfe.mp3 (with local cache)
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/half_of_the_time_4b2bfe.png (with local cache)
# Creating notes:  38%|███▊      | 27/72 [00:10<00:14,  3.04it/s]
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase it_moves_slowly_cec6a3 - nl-NL translation only
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:11 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/it_moves_slowly_cec6a3.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/it_moves_slowly_cec6a3.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/it_moves_slowly_cec6a3.png (with local cache)
# Creating notes:  39%|███▉      | 28/72 [00:10<00:14,  3.02it/s]
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase please_move_over_c9ea26 - nl-NL translation only
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/please_move_over_c9ea26.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/please_move_over_c9ea26.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/please_move_over_c9ea26.png (with local cache)
# Creating notes:  40%|████      | 29/72 [00:10<00:14,  3.00it/s]
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase the_cold_winter_weather_ad8d43 - nl-NL translation only
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/the_cold_winter_weather_ad8d43.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/the_cold_winter_weather_ad8d43.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/the_cold_winter_weather_ad8d43.png (with local cache)
# Creating notes:  42%|████▏     | 30/72 [00:11<00:13,  3.06it/s]
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase can_you_explain_this_4acf9d - nl-NL translation only
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/can_you_explain_this_4acf9d.mp3 (with local cache)
# 2026-05-02 18:12:12 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/can_you_explain_this_4acf9d.mp3 (with local cache)
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/can_you_explain_this_4acf9d.png (with local cache)
# Creating notes:  43%|████▎     | 31/72 [00:11<00:13,  3.06it/s]
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase certainly_the_right_point_69820f - nl-NL translation only
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/certainly_the_right_point_69820f.mp3 (with local cache)
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/certainly_the_right_point_69820f.mp3 (with local cache)
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/certainly_the_right_point_69820f.png (with local cache)
# Creating notes:  44%|████▍     | 32/72 [00:11<00:13,  3.03it/s]
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase he_runs_a_business_93ea89 - nl-NL translation only
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/he_runs_a_business_93ea89.mp3 (with local cache)
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/he_runs_a_business_93ea89.mp3 (with local cache)
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/he_runs_a_business_93ea89.png (with local cache)
# Creating notes:  46%|████▌     | 33/72 [00:12<00:13,  2.97it/s]
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase please_explain_your_reasoning_98582e - nl-NL translation only
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:13 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/please_explain_your_reasoning_98582e.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/please_explain_your_reasoning_98582e.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/please_explain_your_reasoning_98582e.png (with local cache)
# Creating notes:  47%|████▋     | 34/72 [00:12<00:12,  2.95it/s]
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_opened_the_window_0c5f0c - nl-NL translation only
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_opened_the_window_0c5f0c.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_opened_the_window_0c5f0c.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_opened_the_window_0c5f0c.png (with local cache)
# Creating notes:  49%|████▊     | 35/72 [00:12<00:12,  2.88it/s]
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase the_human_body_d4d1a9 - nl-NL translation only
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/the_human_body_d4d1a9.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/the_human_body_d4d1a9.mp3 (with local cache)
# 2026-05-02 18:12:14 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/the_human_body_d4d1a9.png (with local cache)
# Creating notes:  50%|█████     | 36/72 [00:13<00:12,  2.78it/s]
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_you_ask_him_b39108 - nl-NL translation only
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_you_ask_him_b39108.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_you_ask_him_b39108.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_you_ask_him_b39108.png (with local cache)
# Creating notes:  51%|█████▏    | 37/72 [00:13<00:12,  2.90it/s]
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_you_open_it_fc908c - nl-NL translation only
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_you_open_it_fc908c.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_you_open_it_fc908c.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_you_open_it_fc908c.png (with local cache)
# Creating notes:  53%|█████▎    | 38/72 [00:13<00:11,  2.88it/s]
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase a_pretty_blue_flower_769e8e - nl-NL translation only
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/a_pretty_blue_flower_769e8e.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/a_pretty_blue_flower_769e8e.mp3 (with local cache)
# 2026-05-02 18:12:15 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/a_pretty_blue_flower_769e8e.png (with local cache)
# Creating notes:  54%|█████▍    | 39/72 [00:14<00:11,  2.83it/s]
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase apparently_shes_single_1c829f - nl-NL translation only
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/apparently_shes_single_1c829f.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/apparently_shes_single_1c829f.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/apparently_shes_single_1c829f.png (with local cache)
# Creating notes:  56%|█████▌    | 40/72 [00:14<00:11,  2.73it/s]
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase a_fact_about_the_world_ba49e6 - nl-NL translation only
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/a_fact_about_the_world_ba49e6.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/a_fact_about_the_world_ba49e6.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/a_fact_about_the_world_ba49e6.png (with local cache)
# Creating notes:  57%|█████▋    | 41/72 [00:14<00:11,  2.78it/s]
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase around_an_ordinary_office_719ab5 - nl-NL translation only
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/around_an_ordinary_office_719ab5.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/around_an_ordinary_office_719ab5.mp3 (with local cache)
# 2026-05-02 18:12:16 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/around_an_ordinary_office_719ab5.png (with local cache)
# Creating notes:  58%|█████▊    | 42/72 [00:15<00:10,  2.90it/s]
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_explains_the_concept_1e076c - nl-NL translation only
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_explains_the_concept_1e076c.mp3 (with local cache)
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_explains_the_concept_1e076c.mp3 (with local cache)
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_explains_the_concept_1e076c.png (with local cache)
# Creating notes:  60%|█████▉    | 43/72 [00:15<00:10,  2.80it/s]
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase will_you_run_tomorrow_526c27 - nl-NL translation only
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/will_you_run_tomorrow_526c27.mp3 (with local cache)
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/will_you_run_tomorrow_526c27.mp3 (with local cache)
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/will_you_run_tomorrow_526c27.png (with local cache)
# Creating notes:  61%|██████    | 44/72 [00:16<00:10,  2.78it/s]
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase my_fathers_old_watch_c6a0ba - nl-NL translation only
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/my_fathers_old_watch_c6a0ba.mp3 (with local cache)
# 2026-05-02 18:12:17 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/my_fathers_old_watch_c6a0ba.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/my_fathers_old_watch_c6a0ba.png (with local cache)
# Creating notes:  62%|██████▎   | 45/72 [00:16<00:09,  2.82it/s]
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase open_your_book_please_feae3d - nl-NL translation only
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/open_your_book_please_feae3d.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/open_your_book_please_feae3d.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/open_your_book_please_feae3d.png (with local cache)
# Creating notes:  64%|██████▍   | 46/72 [00:16<00:09,  2.87it/s]
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase please_follow_the_path_af166e - nl-NL translation only
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/please_follow_the_path_af166e.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/please_follow_the_path_af166e.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/please_follow_the_path_af166e.png (with local cache)
# Creating notes:  65%|██████▌   | 47/72 [00:17<00:08,  3.02it/s]
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase shall_we_open_it_731166 - nl-NL translation only
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/shall_we_open_it_731166.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/shall_we_open_it_731166.mp3 (with local cache)
# 2026-05-02 18:12:18 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/shall_we_open_it_731166.png (with local cache)
# Creating notes:  67%|██████▋   | 48/72 [00:17<00:07,  3.07it/s]
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase is_there_anybody_in_the_room_f40d8a - nl-NL translation only
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/is_there_anybody_in_the_room_f40d8a.mp3 (with local cache)
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/is_there_anybody_in_the_room_f40d8a.mp3 (with local cache)
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/is_there_anybody_in_the_room_f40d8a.png (with local cache)
# Creating notes:  68%|██████▊   | 49/72 [00:17<00:07,  3.08it/s]
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase our_budget_is_1000_488d79 - nl-NL translation only
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/our_budget_is_1000_488d79.mp3 (with local cache)
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/our_budget_is_1000_488d79.mp3 (with local cache)
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/our_budget_is_1000_488d79.png (with local cache)
# Creating notes:  69%|██████▉   | 50/72 [00:18<00:07,  2.95it/s]
# 2026-05-02 18:12:19 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase the_lecture_follows_dinner_c99418 - nl-NL translation only
# ...
# 2026-05-02 18:12:21 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_followed_the_instructions_afa5c9.png (with local cache)
# Creating notes:  78%|███████▊  | 56/72 [00:20<00:05,  2.70it/s]
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_run_every_morning_983cd0 - nl-NL translation only
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_run_every_morning_983cd0.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_run_every_morning_983cd0.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_run_every_morning_983cd0.png (with local cache)
# Creating notes:  79%|███████▉  | 57/72 [00:20<00:05,  2.82it/s]
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase it_was_a_large_order_9532a0 - nl-NL translation only
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/it_was_a_large_order_9532a0.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/it_was_a_large_order_9532a0.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/it_was_a_large_order_9532a0.png (with local cache)
# Creating notes:  81%|████████  | 58/72 [00:20<00:04,  2.87it/s]
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase less_sugar_in_my_coffee_6d5a52 - nl-NL translation only
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/less_sugar_in_my_coffee_6d5a52.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/less_sugar_in_my_coffee_6d5a52.mp3 (with local cache)
# 2026-05-02 18:12:22 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/less_sugar_in_my_coffee_6d5a52.png (with local cache)
# Creating notes:  82%|████████▏ | 59/72 [00:21<00:04,  2.74it/s]
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase quite_a_beautiful_sunset_89d101 - nl-NL translation only
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/quite_a_beautiful_sunset_89d101.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/quite_a_beautiful_sunset_89d101.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/quite_a_beautiful_sunset_89d101.png (with local cache)
# Creating notes:  83%|████████▎ | 60/72 [00:21<00:04,  2.72it/s]
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase they_moved_to_paris_509063 - nl-NL translation only
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/they_moved_to_paris_509063.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/they_moved_to_paris_509063.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/they_moved_to_paris_509063.png (with local cache)
# Creating notes:  85%|████████▍ | 61/72 [00:21<00:03,  2.76it/s]
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase it_figures_prominently_67f1cf - nl-NL translation only
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/it_figures_prominently_67f1cf.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/it_figures_prominently_67f1cf.mp3 (with local cache)
# 2026-05-02 18:12:23 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/it_figures_prominently_67f1cf.png (with local cache)
# Creating notes:  86%|████████▌ | 62/72 [00:22<00:03,  2.62it/s]
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase we_will_move_soon_7e382b - nl-NL translation only
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/we_will_move_soon_7e382b.mp3 (with local cache)
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/we_will_move_soon_7e382b.mp3 (with local cache)
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/we_will_move_soon_7e382b.png (with local cache)
# Creating notes:  88%|████████▊ | 63/72 [00:22<00:03,  2.74it/s]
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase we_won_the_game_3befb7 - nl-NL translation only
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/we_won_the_game_3befb7.mp3 (with local cache)
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/we_won_the_game_3befb7.mp3 (with local cache)
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/we_won_the_game_3befb7.png (with local cache)
# Creating notes:  89%|████████▉ | 64/72 [00:23<00:02,  2.82it/s]
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase when_will_they_realise_2ffd97 - nl-NL translation only
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/when_will_they_realise_2ffd97.mp3 (with local cache)
# 2026-05-02 18:12:24 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/when_will_they_realise_2ffd97.mp3 (with local cache)
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/when_will_they_realise_2ffd97.png (with local cache)
# Creating notes:  90%|█████████ | 65/72 [00:23<00:02,  2.81it/s]
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase a_serious_medical_condition_c1a89b - nl-NL translation only
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/a_serious_medical_condition_c1a89b.mp3 (with local cache)
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/a_serious_medical_condition_c1a89b.mp3 (with local cache)
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/a_serious_medical_condition_c1a89b.png (with local cache)
# Creating notes:  92%|█████████▏| 66/72 [00:23<00:02,  2.80it/s]
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase an_officer_at_the_college_7ae8f9 - nl-NL translation only
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/an_officer_at_the_college_7ae8f9.mp3 (with local cache)
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/an_officer_at_the_college_7ae8f9.mp3 (with local cache)
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/an_officer_at_the_college_7ae8f9.png (with local cache)
# Creating notes:  93%|█████████▎| 67/72 [00:24<00:01,  2.77it/s]
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase i_explained_my_decision_ccf3d1 - nl-NL translation only
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:25 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/i_explained_my_decision_ccf3d1.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/i_explained_my_decision_ccf3d1.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/i_explained_my_decision_ccf3d1.png (with local cache)
# Creating notes:  94%|█████████▍| 68/72 [00:24<00:01,  2.76it/s]
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_wears_blue_jeans_f90020 - nl-NL translation only
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_wears_blue_jeans_f90020.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_wears_blue_jeans_f90020.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_wears_blue_jeans_f90020.png (with local cache)
# Creating notes:  96%|█████████▌| 69/72 [00:24<00:01,  2.79it/s]
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase there_are_people_behind_the_office_c7a139 - nl-NL translation only
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/there_are_people_behind_the_office_c7a139.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/there_are_people_behind_the_office_c7a139.mp3 (with local cache)
# 2026-05-02 18:12:26 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/there_are_people_behind_the_office_c7a139.png (with local cache)
# Creating notes:  97%|█████████▋| 70/72 [00:25<00:00,  2.77it/s]
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase she_realised_the_truth_3cd5a1 - nl-NL translation only
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/she_realised_the_truth_3cd5a1.mp3 (with local cache)
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/she_realised_the_truth_3cd5a1.mp3 (with local cache)
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/she_realised_the_truth_3cd5a1.png (with local cache)
# Creating notes:  99%|█████████▊| 71/72 [00:25<00:00,  2.84it/s]
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:419 - Downloading multimedia for phrase its_about_his_trust_issues_fb574c - nl-NL translation only
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:1009 - Downloading all multimedia for nl-NL translation
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/slow from phrases/nl-NL/audio/flashcard/slow/its_about_his_trust_issues_fb574c.mp3 (with local cache)
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:852 - Downloading audio: nl-NL flashcard/normal from phrases/nl-NL/audio/flashcard/normal/its_about_his_trust_issues_fb574c.mp3 (with local cache)
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - phrase_model.py:1122 - Downloading image: nl-NL from phrases/en-GB/images/its_about_his_trust_issues_fb574c.png (with local cache)
# Creating notes: 100%|██████████| 72/72 [00:25<00:00,  2.78it/s]
# Adding notes to deck: 100%|██████████| 72/72 [00:00<?, ?it/s]
# 2026-05-02 18:12:27 - audio-language-trainer - INFO - anki_tools.py:384 - (y) Created deck with 72 notes
# 2026-05-02 18:12:29 - audio-language-trainer - INFO - anki_tools.py:390 - Saved Anki Deck to ../outputs/decks/nl-NL/nl-NL-LM1000-Pack01.apkg

# %%
phrases[0].translations.keys()
