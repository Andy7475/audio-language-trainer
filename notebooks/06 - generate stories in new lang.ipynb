# %%
# %load_ext autoreload
# %autoreload 2

from setup_imports import *  # noqa: F401,F403
from story import get_all_stories, get_story
from challenges.models import get_challenge_by_story
from langcodes import Language

# %% [markdown]
# ## Get story and publish

# %%
TARGET_LANGUAGE = Language.get("nl-NL")
print(TARGET_LANGUAGE.display_name())
SOURCE_LANGUAGE = Language.get("sv-SE")
print(SOURCE_LANGUAGE.display_name())
# Out:
# Dutch (Netherlands)
# Swedish (Sweden)

# %%
all_stories = get_all_stories("LM1000")

# %%
s = get_story(story_title="A Winter Morning Walk")
# Out:
# (y) Authenticated with Google Cloud project: swedish-course

# %%
s.translate(target_language=TARGET_LANGUAGE, refine=True, split_on_space=True, overwrite=True)
#s.upload(language=TARGET_LANGUAGE)
s.generate_audio(language=TARGET_LANGUAGE, overwrite=True, split_on_space=True)
s.upload(language=TARGET_LANGUAGE, overwrite=True)
s.publish_story(source_language=SOURCE_LANGUAGE, target_language=TARGET_LANGUAGE, overwrite=True, split_on_space=True)
# Out:
# (y) Google Translate API client initialized
# (y) Natural Language API client initialized
# 2026-05-02 17:36:37 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:37 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goedemorgen, Sam! Het is vandaag behoorlijk koud buiten.
# 2026-05-02 17:36:37 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goedemorgen, Sam! Het is vandaag behoorlijk koud buiten. - tokens: ['Goedemorgen,', 'Sam!', 'Het', 'is', 'vandaag', 'behoorlijk', 'koud', 'buiten.']
# 2026-05-02 17:36:38 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:38 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goedemorgen, Alex! Ja, het is inderdaad koud. Het is tenslotte winter.
# 2026-05-02 17:36:38 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goedemorgen, Alex! Ja, het is inderdaad koud. Het is tenslotte winter. - tokens: ['Goedemorgen,', 'Alex!', 'Ja,', 'het', 'is', 'inderdaad', 'koud.', 'Het', 'is', 'tenslotte', 'winter.']
# 2026-05-02 17:36:39 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:39 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik wil graag een wandeling maken. Ga je met me mee?
# 2026-05-02 17:36:39 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik wil graag een wandeling maken. Ga je met me mee? - tokens: ['Ik', 'wil', 'graag', 'een', 'wandeling', 'maken.', 'Ga', 'je', 'met', 'me', 'mee?']
# 2026-05-02 17:36:39 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:39 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Natuurlijk! Ik maak me even klaar. Wat zal ik aantrekken?
# 2026-05-02 17:36:39 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Natuurlijk! Ik maak me even klaar. Wat zal ik aantrekken? - tokens: ['Natuurlijk!', 'Ik', 'maak', 'me', 'even', 'klaar.', 'Wat', 'zal', 'ik', 'aantrekken?']
# 2026-05-02 17:36:40 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:40 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Je moet je blauwe spijkerbroek en een pet aantrekken. Oh, en vergeet je koffie niet. Die kunnen we onderweg opdrinken.
# 2026-05-02 17:36:40 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Je moet je blauwe spijkerbroek en een pet aantrekken. Oh, en vergeet je koffie niet. Die kunnen we onderweg opdrinken. - tokens: ['Je', 'moet', 'je', 'blauwe', 'spijkerbroek', 'en', 'een', 'pet', 'aantrekken.', 'Oh,', 'en', 'vergeet', 'je', 'koffie', 'niet.', 'Die', 'kunnen', 'we', 'onderweg', 'opdrinken.']
# 2026-05-02 17:36:41 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:41 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goed idee. Ik open eerst even het raam om te kijken hoe koud het is.
# 2026-05-02 17:36:41 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goed idee. Ik open eerst even het raam om te kijken hoe koud het is. - tokens: ['Goed', 'idee.', 'Ik', 'open', 'eerst', 'even', 'het', 'raam', 'om', 'te', 'kijken', 'hoe', 'koud', 'het', 'is.']
# 2026-05-02 17:36:42 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:42 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Er staat water in de badkamer. Heb je de kraan open laten staan?
# 2026-05-02 17:36:42 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Er staat water in de badkamer. Heb je de kraan open laten staan? - tokens: ['Er', 'staat', 'water', 'in', 'de', 'badkamer.', 'Heb', 'je', 'de', 'kraan', 'open', 'laten', 'staan?']
# 2026-05-02 17:36:43 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:43 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Oh! Ik ga hem even uitzetten. Kun je bij de deur op me wachten?
# 2026-05-02 17:36:43 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Oh! Ik ga hem even uitzetten. Kun je bij de deur op me wachten? - tokens: ['Oh!', 'Ik', 'ga', 'hem', 'even', 'uitzetten.', 'Kun', 'je', 'bij', 'de', 'deur', 'op', 'me', 'wachten?']
# 2026-05-02 17:36:44 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:44 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Dit pad is prachtig met al die sneeuw. Kijk eens naar de bomen!
# 2026-05-02 17:36:44 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Dit pad is prachtig met al die sneeuw. Kijk eens naar de bomen! - tokens: ['Dit', 'pad', 'is', 'prachtig', 'met', 'al', 'die', 'sneeuw.', 'Kijk', 'eens', 'naar', 'de', 'bomen!']
# 2026-05-02 17:36:44 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:44 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ja, het is prachtig. De zonsondergang van gisteren was ook schitterend. Ik heb hem vanuit ons raam bekeken.
# 2026-05-02 17:36:44 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ja, het is prachtig. De zonsondergang van gisteren was ook schitterend. Ik heb hem vanuit ons raam bekeken. - tokens: ['Ja,', 'het', 'is', 'prachtig.', 'De', 'zonsondergang', 'van', 'gisteren', 'was', 'ook', 'schitterend.', 'Ik', 'heb', 'hem', 'vanuit', 'ons', 'raam', 'bekeken.']
# 2026-05-02 17:36:45 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:45 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Wacht, ik denk dat we de verkeerde kant op gaan. Dit klopt niet.
# 2026-05-02 17:36:45 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Wacht, ik denk dat we de verkeerde kant op gaan. Dit klopt niet. - tokens: ['Wacht,', 'ik', 'denk', 'dat', 'we', 'de', 'verkeerde', 'kant', 'op', 'gaan.', 'Dit', 'klopt', 'niet.']
# 2026-05-02 17:36:46 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:46 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Hmm, je hebt misschien gelijk. Ik herken dit deel van het park niet.
# 2026-05-02 17:36:46 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Hmm, je hebt misschien gelijk. Ik herken dit deel van het park niet. - tokens: ['Hmm,', 'je', 'hebt', 'misschien', 'gelijk.', 'Ik', 'herken', 'dit', 'deel', 'van', 'het', 'park', 'niet.']
# 2026-05-02 17:36:47 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:47 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik denk dat we de weg kwijt zijn. Dit is een beetje lastig.
# 2026-05-02 17:36:47 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik denk dat we de weg kwijt zijn. Dit is een beetje lastig. - tokens: ['Ik', 'denk', 'dat', 'we', 'de', 'weg', 'kwijt', 'zijn.', 'Dit', 'is', 'een', 'beetje', 'lastig.']
# 2026-05-02 17:36:48 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:48 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Geen zorgen. Ik kan wel de weg vragen. Er is iemand daar.
# 2026-05-02 17:36:48 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Geen zorgen. Ik kan wel de weg vragen. Er is iemand daar. - tokens: ['Geen', 'zorgen.', 'Ik', 'kan', 'wel', 'de', 'weg', 'vragen.', 'Er', 'is', 'iemand', 'daar.']
# 2026-05-02 17:36:48 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:48 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goed idee. Ik verdwaal de helft van de tijd in dit park.
# 2026-05-02 17:36:48 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goed idee. Ik verdwaal de helft van de tijd in dit park. - tokens: ['Goed', 'idee.', 'Ik', 'verdwaal', 'de', 'helft', 'van', 'de', 'tijd', 'in', 'dit', 'park.']
# 2026-05-02 17:36:49 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:49 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik ga even met hem praten. Wacht u alstublieft even hier.
# 2026-05-02 17:36:49 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik ga even met hem praten. Wacht u alstublieft even hier. - tokens: ['Ik', 'ga', 'even', 'met', 'hem', 'praten.', 'Wacht', 'u', 'alstublieft', 'even', 'hier.']
# 2026-05-02 17:36:50 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:50 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Oké, ik heb de informatie die we nodig hebben. De man was erg behulpzaam.
# 2026-05-02 17:36:50 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Oké, ik heb de informatie die we nodig hebben. De man was erg behulpzaam. - tokens: ['Oké,', 'ik', 'heb', 'de', 'informatie', 'die', 'we', 'nodig', 'hebben.', 'De', 'man', 'was', 'erg', 'behulpzaam.']
# 2026-05-02 17:36:50 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:50 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Geweldig! Wat zei hij?
# 2026-05-02 17:36:50 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Geweldig! Wat zei hij? - tokens: ['Geweldig!', 'Wat', 'zei', 'hij?']
# 2026-05-02 17:36:51 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:51 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Hij zei dat we rechtdoor moesten gaan en dan bij de grote winkel rechtsaf moesten slaan.
# 2026-05-02 17:36:51 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Hij zei dat we rechtdoor moesten gaan en dan bij de grote winkel rechtsaf moesten slaan. - tokens: ['Hij', 'zei', 'dat', 'we', 'rechtdoor', 'moesten', 'gaan', 'en', 'dan', 'bij', 'de', 'grote', 'winkel', 'rechtsaf', 'moesten', 'slaan.']
# 2026-05-02 17:36:52 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:52 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ah, ik zie het nu! Die winkel staat me nog helder voor de geest. We zijn vlakbij huis.
# 2026-05-02 17:36:52 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ah, ik zie het nu! Die winkel staat me nog helder voor de geest. We zijn vlakbij huis. - tokens: ['Ah,', 'ik', 'zie', 'het', 'nu!', 'Die', 'winkel', 'staat', 'me', 'nog', 'helder', 'voor', 'de', 'geest.', 'We', 'zijn', 'vlakbij', 'huis.']
# 2026-05-02 17:36:52 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:52 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ja! En kijk, daar is onze vriend Tom.
# 2026-05-02 17:36:52 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ja! En kijk, daar is onze vriend Tom. - tokens: ['Ja!', 'En', 'kijk,', 'daar', 'is', 'onze', 'vriend', 'Tom.']
# 2026-05-02 17:36:53 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:53 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Zullen we hem openmaken? De koffie, bedoel ik. Ik heb het koud en zou graag iets drinken.
# 2026-05-02 17:36:53 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zullen we hem openmaken? De koffie, bedoel ik. Ik heb het koud en zou graag iets drinken. - tokens: ['Zullen', 'we', 'hem', 'openmaken?', 'De', 'koffie,', 'bedoel', 'ik.', 'Ik', 'heb', 'het', 'koud', 'en', 'zou', 'graag', 'iets', 'drinken.']
# 2026-05-02 17:36:54 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:54 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Zeker! Laten we het samen opdrinken en dan naar huis gaan.
# 2026-05-02 17:36:54 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zeker! Laten we het samen opdrinken en dan naar huis gaan. - tokens: ['Zeker!', 'Laten', 'we', 'het', 'samen', 'opdrinken', 'en', 'dan', 'naar', 'huis', 'gaan.']
# 2026-05-02 17:36:55 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:55 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Het was een fijne ochtendwandeling, ondanks ons kleine foutje. Morgen proberen we een ander pad.
# 2026-05-02 17:36:55 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het was een fijne ochtendwandeling, ondanks ons kleine foutje. Morgen proberen we een ander pad. - tokens: ['Het', 'was', 'een', 'fijne', 'ochtendwandeling,', 'ondanks', 'ons', 'kleine', 'foutje.', 'Morgen', 'proberen', 'we', 'een', 'ander', 'pad.']
# 2026-05-02 17:36:55 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:36:55 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Dat lijkt me leuk. Dan kunnen we samen een groter deel van het park verkennen.
# 2026-05-02 17:36:55 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Dat lijkt me leuk. Dan kunnen we samen een groter deel van het park verkennen. - tokens: ['Dat', 'lijkt', 'me', 'leuk.', 'Dan', 'kunnen', 'we', 'samen', 'een', 'groter', 'deel', 'van', 'het', 'park', 'verkennen.']
# 2026-05-02 17:37:20 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:20 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goedemorgen, Sam! Het is vandaag behoorlijk koud buiten.
# 2026-05-02 17:37:20 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goedemorgen, Sam! Het is vandaag behoorlijk koud buiten. - tokens: ['Goedemorgen,', 'Sam!', 'Het', 'is', 'vandaag', 'behoorlijk', 'koud', 'buiten.']
# 2026-05-02 17:37:21 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:21 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Morgen, Alex! Ja, het is inderdaad koud. Het is tenslotte winter.
# 2026-05-02 17:37:21 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Morgen, Alex! Ja, het is inderdaad koud. Het is tenslotte winter. - tokens: ['Morgen,', 'Alex!', 'Ja,', 'het', 'is', 'inderdaad', 'koud.', 'Het', 'is', 'tenslotte', 'winter.']
# 2026-05-02 17:37:22 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:22 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik wil graag een wandeling maken. Ga je met me mee?
# 2026-05-02 17:37:22 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik wil graag een wandeling maken. Ga je met me mee? - tokens: ['Ik', 'wil', 'graag', 'een', 'wandeling', 'maken.', 'Ga', 'je', 'met', 'me', 'mee?']
# 2026-05-02 17:37:22 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:22 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Tuurlijk! Laat me even klaar maken. Wat zal ik aantrekken?
# 2026-05-02 17:37:22 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Tuurlijk! Laat me even klaar maken. Wat zal ik aantrekken? - tokens: ['Tuurlijk!', 'Laat', 'me', 'even', 'klaar', 'maken.', 'Wat', 'zal', 'ik', 'aantrekken?']
# 2026-05-02 17:37:23 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:23 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Trek je blauwe spijkerbroek aan en een muts. Oh, en vergeet je koffie niet. Die kunnen we onderweg opdrinken.
# 2026-05-02 17:37:23 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Trek je blauwe spijkerbroek aan en een muts. Oh, en vergeet je koffie niet. Die kunnen we onderweg opdrinken. - tokens: ['Trek', 'je', 'blauwe', 'spijkerbroek', 'aan', 'en', 'een', 'muts.', 'Oh,', 'en', 'vergeet', 'je', 'koffie', 'niet.', 'Die', 'kunnen', 'we', 'onderweg', 'opdrinken.']
# 2026-05-02 17:37:24 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:24 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goed idee. Ik doe eerst even het raam open om te kijken hoe koud het is.
# 2026-05-02 17:37:24 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goed idee. Ik doe eerst even het raam open om te kijken hoe koud het is. - tokens: ['Goed', 'idee.', 'Ik', 'doe', 'eerst', 'even', 'het', 'raam', 'open', 'om', 'te', 'kijken', 'hoe', 'koud', 'het', 'is.']
# 2026-05-02 17:37:24 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:24 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Het water loopt in de badkamer. Heb je de kraan laten lopen?
# 2026-05-02 17:37:24 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het water loopt in de badkamer. Heb je de kraan laten lopen? - tokens: ['Het', 'water', 'loopt', 'in', 'de', 'badkamer.', 'Heb', 'je', 'de', 'kraan', 'laten', 'lopen?']
# 2026-05-02 17:37:25 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:25 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Oh! Ik ga hem even uitdraaien. Kun je bij de deur op me wachten?
# 2026-05-02 17:37:25 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Oh! Ik ga hem even uitdraaien. Kun je bij de deur op me wachten? - tokens: ['Oh!', 'Ik', 'ga', 'hem', 'even', 'uitdraaien.', 'Kun', 'je', 'bij', 'de', 'deur', 'op', 'me', 'wachten?']
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Dit pad is prachtig met al die sneeuw. Kijk eens naar de bomen!
# 2026-05-02 17:37:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Dit pad is prachtig met al die sneeuw. Kijk eens naar de bomen! - tokens: ['Dit', 'pad', 'is', 'prachtig', 'met', 'al', 'die', 'sneeuw.', 'Kijk', 'eens', 'naar', 'de', 'bomen!']
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ja, het is prachtig. De zonsondergang gisteren was ook mooi. Ik heb hem vanuit ons raam bekeken.
# 2026-05-02 17:37:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ja, het is prachtig. De zonsondergang gisteren was ook mooi. Ik heb hem vanuit ons raam bekeken. - tokens: ['Ja,', 'het', 'is', 'prachtig.', 'De', 'zonsondergang', 'gisteren', 'was', 'ook', 'mooi.', 'Ik', 'heb', 'hem', 'vanuit', 'ons', 'raam', 'bekeken.']
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:26 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Wacht, ik denk dat we de verkeerde kant op gaan. Dit klopt niet.
# 2026-05-02 17:37:26 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Wacht, ik denk dat we de verkeerde kant op gaan. Dit klopt niet. - tokens: ['Wacht,', 'ik', 'denk', 'dat', 'we', 'de', 'verkeerde', 'kant', 'op', 'gaan.', 'Dit', 'klopt', 'niet.']
# 2026-05-02 17:37:27 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:27 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Hmm, je hebt misschien gelijk. Ik herken dit deel van het park niet.
# 2026-05-02 17:37:27 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Hmm, je hebt misschien gelijk. Ik herken dit deel van het park niet. - tokens: ['Hmm,', 'je', 'hebt', 'misschien', 'gelijk.', 'Ik', 'herken', 'dit', 'deel', 'van', 'het', 'park', 'niet.']
# 2026-05-02 17:37:27 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:27 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik denk dat we verdwaald zijn. Dit is een beetje lastig.
# 2026-05-02 17:37:27 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik denk dat we verdwaald zijn. Dit is een beetje lastig. - tokens: ['Ik', 'denk', 'dat', 'we', 'verdwaald', 'zijn.', 'Dit', 'is', 'een', 'beetje', 'lastig.']
# 2026-05-02 17:37:28 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:28 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Geen zorgen. Ik kan de weg vragen. Daar staat iemand.
# 2026-05-02 17:37:28 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Geen zorgen. Ik kan de weg vragen. Daar staat iemand. - tokens: ['Geen', 'zorgen.', 'Ik', 'kan', 'de', 'weg', 'vragen.', 'Daar', 'staat', 'iemand.']
# 2026-05-02 17:37:29 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:29 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Goed idee. De helft van de tijd verdwaal ik in dit park.
# 2026-05-02 17:37:29 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Goed idee. De helft van de tijd verdwaal ik in dit park. - tokens: ['Goed', 'idee.', 'De', 'helft', 'van', 'de', 'tijd', 'verdwaal', 'ik', 'in', 'dit', 'park.']
# 2026-05-02 17:37:29 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:29 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ik ga even met hem praten. Wacht hier even, alsjeblieft.
# 2026-05-02 17:37:29 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ik ga even met hem praten. Wacht hier even, alsjeblieft. - tokens: ['Ik', 'ga', 'even', 'met', 'hem', 'praten.', 'Wacht', 'hier', 'even,', 'alsjeblieft.']
# 2026-05-02 17:37:30 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:30 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Oké, ik heb de informatie die we nodig hebben. De man was erg behulpzaam.
# 2026-05-02 17:37:30 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Oké, ik heb de informatie die we nodig hebben. De man was erg behulpzaam. - tokens: ['Oké,', 'ik', 'heb', 'de', 'informatie', 'die', 'we', 'nodig', 'hebben.', 'De', 'man', 'was', 'erg', 'behulpzaam.']
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Geweldig! Wat zei hij?
# 2026-05-02 17:37:31 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Geweldig! Wat zei hij? - tokens: ['Geweldig!', 'Wat', 'zei', 'hij?']
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Hij zei dat we rechtdoor moeten en dan bij de grote winkel rechtsaf.
# 2026-05-02 17:37:31 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Hij zei dat we rechtdoor moeten en dan bij de grote winkel rechtsaf. - tokens: ['Hij', 'zei', 'dat', 'we', 'rechtdoor', 'moeten', 'en', 'dan', 'bij', 'de', 'grote', 'winkel', 'rechtsaf.']
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:31 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ah, ik zie het nu! Die winkel herinner ik me nog goed. We zijn vlakbij huis.
# 2026-05-02 17:37:31 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ah, ik zie het nu! Die winkel herinner ik me nog goed. We zijn vlakbij huis. - tokens: ['Ah,', 'ik', 'zie', 'het', 'nu!', 'Die', 'winkel', 'herinner', 'ik', 'me', 'nog', 'goed.', 'We', 'zijn', 'vlakbij', 'huis.']
# 2026-05-02 17:37:32 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:32 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Ja! En kijk, daar is onze vriend Tom.
# 2026-05-02 17:37:32 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Ja! En kijk, daar is onze vriend Tom. - tokens: ['Ja!', 'En', 'kijk,', 'daar', 'is', 'onze', 'vriend', 'Tom.']
# 2026-05-02 17:37:33 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:33 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Zullen we hem openmaken? De koffie, bedoel ik. Ik heb het koud en wil graag wat drinken.
# 2026-05-02 17:37:33 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zullen we hem openmaken? De koffie, bedoel ik. Ik heb het koud en wil graag wat drinken. - tokens: ['Zullen', 'we', 'hem', 'openmaken?', 'De', 'koffie,', 'bedoel', 'ik.', 'Ik', 'heb', 'het', 'koud', 'en', 'wil', 'graag', 'wat', 'drinken.']
# 2026-05-02 17:37:33 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:33 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Zeker! Laten we hem samen opdrinken en dan naar huis gaan.
# 2026-05-02 17:37:33 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Zeker! Laten we hem samen opdrinken en dan naar huis gaan. - tokens: ['Zeker!', 'Laten', 'we', 'hem', 'samen', 'opdrinken', 'en', 'dan', 'naar', 'huis', 'gaan.']
# 2026-05-02 17:37:34 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:34 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Het was een fijne ochtendwandeling, ondanks ons kleine foutje. Morgen proberen we een ander pad.
# 2026-05-02 17:37:34 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Het was een fijne ochtendwandeling, ondanks ons kleine foutje. Morgen proberen we een ander pad. - tokens: ['Het', 'was', 'een', 'fijne', 'ochtendwandeling,', 'ondanks', 'ons', 'kleine', 'foutje.', 'Morgen', 'proberen', 'we', 'een', 'ander', 'pad.']
# 2026-05-02 17:37:35 - audio-language-trainer - WARNING - nlp.py:176 - analyze_text_syntax: language not supported by Google NLP: nl
# 2026-05-02 17:37:35 - audio-language-trainer - WARNING - nlp.py:227 - extract_lemmas_and_pos: no backend could process phrase for language 'nl': Dat lijkt me leuk. Dan kunnen we meer van het park verkennen.
# 2026-05-02 17:37:35 - audio-language-trainer - INFO - phrase_model.py:354 - (y) Created translation for nl-NL: Dat lijkt me leuk. Dan kunnen we meer van het park verkennen. - tokens: ['Dat', 'lijkt', 'me', 'leuk.', 'Dan', 'kunnen', 'we', 'meer', 'van', 'het', 'park', 'verkennen.']
# (y) Google Text-to-Speech API client initialized
# 2026-05-02 17:37:55 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a with nl-NL translation to Firestore and GCS
# 2026-05-02 17:37:55 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# (y) Google Cloud Storage client initialized
# 2026-05-02 17:37:57 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a.mp3 (local cache enabled)
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#1#morning_alex_yes_the_weather_is_definitely_cold_it_81d791 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#1#morning_alex_yes_the_weather_is_definitely_cold_it_81d791.mp3 (local cache enabled)
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#2#i_want_to_go_for_a_walk_will_you_come_with_me_1936ea with nl-NL translation to Firestore and GCS
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:37:58 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#2#i_want_to_go_for_a_walk_will_you_come_with_me_1936ea.mp3 (local cache enabled)
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#3#sure_just_let_me_get_ready_what_should_i_wear_80190a with nl-NL translation to Firestore and GCS
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#3#sure_just_let_me_get_ready_what_should_i_wear_80190a.mp3 (local cache enabled)
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#4#you_should_wear_your_blue_jeans_and_a_hat_oh_and_d_bbd252 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:37:59 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#4#you_should_wear_your_blue_jeans_and_a_hat_oh_and_d_bbd252.mp3 (local cache enabled)
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#5#good_idea_ill_open_the_window_first_to_check_how_c_b84bda with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#5#good_idea_ill_open_the_window_first_to_check_how_c_b84bda.mp3 (local cache enabled)
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#6#the_water_is_running_in_the_bathroom_did_you_leave_6840e4 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#6#the_water_is_running_in_the_bathroom_did_you_leave_6840e4.mp3 (local cache enabled)
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_1#7#oh_ill_go_and_turn_it_off_can_you_wait_for_me_at_t_ed6a59 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:00 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#7#oh_ill_go_and_turn_it_off_can_you_wait_for_me_at_t_ed6a59.mp3 (local cache enabled)
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#0#this_path_is_beautiful_with_all_the_snow_look_at_t_936b9c with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#0#this_path_is_beautiful_with_all_the_snow_look_at_t_936b9c.mp3 (local cache enabled)
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#1#yes_its_lovely_the_sunset_yesterday_was_beautiful__c74cab with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#1#yes_its_lovely_the_sunset_yesterday_was_beautiful__c74cab.mp3 (local cache enabled)
# 2026-05-02 17:38:01 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#2#wait_i_think_were_going_the_wrong_way_this_doesnt__29d417 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#2#wait_i_think_were_going_the_wrong_way_this_doesnt__29d417.mp3 (local cache enabled)
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#3#hmm_you_may_be_right_i_dont_recognize_this_part_of_460fdb with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#3#hmm_you_may_be_right_i_dont_recognize_this_part_of_460fdb.mp3 (local cache enabled)
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#4#i_think_were_lost_this_is_a_little_difficult_a95261 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:02 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#4#i_think_were_lost_this_is_a_little_difficult_a95261.mp3 (local cache enabled)
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#5#dont_worry_i_can_ask_for_directions_theres_a_perso_808b14 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#5#dont_worry_i_can_ask_for_directions_theres_a_perso_808b14.mp3 (local cache enabled)
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#6#good_idea_half_of_the_time_i_get_lost_in_this_park_fffcca with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#6#good_idea_half_of_the_time_i_get_lost_in_this_park_fffcca.mp3 (local cache enabled)
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_2#7#let_me_go_and_talk_to_him_wait_here_please_0a2427 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_2#7#let_me_go_and_talk_to_him_wait_here_please_0a2427.mp3 (local cache enabled)
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#0#ok_i_have_the_information_we_need_the_man_was_very_4a42c5 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:03 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#0#ok_i_have_the_information_we_need_the_man_was_very_4a42c5.mp3 (local cache enabled)
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#1#great_what_did_he_say_69aca0 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#1#great_what_did_he_say_69aca0.mp3 (local cache enabled)
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#2#he_said_we_should_go_straight_and_then_turn_right__dd8fdd with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#2#he_said_we_should_go_straight_and_then_turn_right__dd8fdd.mp3 (local cache enabled)
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#3#ah_i_see_it_now_that_store_figures_prominently_in__10284f with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#3#ah_i_see_it_now_that_store_figures_prominently_in__10284f.mp3 (local cache enabled)
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:04 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3 (local cache enabled)
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3 (local cache enabled)
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3 (local cache enabled)
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5 with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:813 - Uploading audio: nl-NL story/normal to phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3 (local cache enabled)
# 2026-05-02 17:38:05 - audio-language-trainer - INFO - phrase_model.py:384 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f with nl-NL translation to Firestore and GCS
# 2026-05-02 17:38:06 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# ...
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for it-IT translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/it-IT/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for ru-RU translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/ru-RU/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sr-RS translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sr-RS/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sv-SE translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sv-SE/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for uk-UA translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#4#yes_and_look_theres_our_friend_tom_over_there_a80e8e.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:388 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7 with all translations to Firestore and GCS
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for cmn-CN translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/cmn-CN/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for en-GB translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/en-GB/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for fr-FR translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/fr-FR/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for it-IT translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/it-IT/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for ru-RU translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/ru-RU/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sr-RS translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sr-RS/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sv-SE translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sv-SE/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for uk-UA translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#5#shall_we_open_it_the_coffee_i_mean_im_cold_and_wou_8652a7.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:388 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1 with all translations to Firestore and GCS
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for cmn-CN translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/cmn-CN/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for en-GB translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/en-GB/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for fr-FR translation
# 2026-05-02 17:38:26 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/fr-FR/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for it-IT translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/it-IT/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for ru-RU translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/ru-RU/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sr-RS translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sr-RS/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sv-SE translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sv-SE/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for uk-UA translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#6#certainly_lets_drink_it_together_and_then_go_home_2b19c1.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:388 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5 with all translations to Firestore and GCS
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for cmn-CN translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/cmn-CN/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for en-GB translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/en-GB/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for fr-FR translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/fr-FR/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for it-IT translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/it-IT/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for ru-RU translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/ru-RU/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sr-RS translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sr-RS/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sv-SE translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sv-SE/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for uk-UA translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#7#this_was_a_nice_morning_walk_even_with_our_little__7e41c5.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:388 - Uploading phrase story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f with all translations to Firestore and GCS
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for cmn-CN translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/cmn-CN/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for en-GB translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/en-GB/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for fr-FR translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/fr-FR/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for it-IT translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/it-IT/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for ru-RU translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/ru-RU/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sr-RS translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sr-RS/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for sv-SE translation
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/sv-SE/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 2026-05-02 17:38:27 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for uk-UA translation
# 2026-05-02 17:38:28 - audio-language-trainer - INFO - phrase_model.py:1043 - Uploading all multimedia for nl-NL translation
# 2026-05-02 17:38:28 - audio-language-trainer - INFO - phrase_model.py:1054 - Audio already exists at phrases/nl-NL/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_3#8#id_like_that_we_can_explore_more_of_the_park_toget_653c1f.mp3, skipping upload
# 'https://storage.googleapis.com/audio-language-trainer-stories/stories/sv-SE/nl-NL/a_winter_morning_walk_d7b5b3/index.html'

# %%
s.publish_story

# %%
s.story_parts['part_1'][3].story_phrase.key

# %%
for story in all_stories[1:]:
    story.translate(target_language=TARGET_LANGUAGE, refine=True, split_on_space=True, overwrite=True)
    story.generate_audio(language=TARGET_LANGUAGE, overwrite=True, split_on_space=True)
    story.upload(language=TARGET_LANGUAGE, overwrite=True)
    story.publish_story(source_language=SOURCE_LANGUAGE, target_language=TARGET_LANGUAGE, overwrite=True, split_on_space=True)
    #challenge = get_challenge_by_story(story)
    #challenge.publish(target_language=TARGET_LANGUAGE, source_language=SOURCE_LANGUAGE)

# %%
story._get_dialogue_with_translations(target_language=TARGET_LANGUAGE)

# %%
s = all_stories[0]

# %%
s._get_dialogue_with_translations(target_language=TARGET_LANGUAGE)

# %%
all_stories
