# %%
# %load_ext autoreload
# %autoreload 2

from setup_imports import *  # noqa: F401,F403
from src.story import get_all_stories, get_story
from langcodes import Language
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Get story and publish

# %%
story = get_story(story_title_hash="flying_to_suprise_the_family_9bb91e")

# %%
target_lang = Language.get("ru-RU")
print(target_lang.display_name())
# Out:
# Russian (Russia)

# %%
all_stories[0].publish_story(target_language=target_lang, overwrite=False)
# Out:
# 2026-01-25 10:48:07 - audio-language-trainer - INFO - story.py:427 - Story 'A Winter Morning Walk' already published for en-GB -> ru-RU

# %%
all_stories = get_all_stories("LM1000", "Pack01")
# Out:
# (y) Authenticated with Google Cloud project: swedish-course

# %%
all_stories
# Out:
# [Story(firestore_collection='stories', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA5412A2A0>, key='a_winter_morning_walk_d7b5b3', title='A Winter Morning Walk', summary='Alex and Sam go for a walk on a cold winter morning and face a small challenge when they get lost, but they work together to find their way back.', story_parts={'part_1': [Utterance(sequence=0, speaker='Alex', text="Good morning, Sam! It's quite cold outside today.", story_phrase=Phrase(firestore_collection='phrases', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA52C502F0>, key='story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a', english="Good morning, Sam! It's quite cold outside today.", english_lower="good morning, sam! it's quite cold outside today.", tokens=['good', 'morning', 'sam', 'it', 'be', 'quite', 'cold', 'outside', 'today'], verbs=['be'], vocab=['good', 'outside', 'today', 'it', 'quite', 'cold', 'sam', 'morning'], translations={'cmn-CN': Translation(firestore_collection='phrases', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA52C90680>, key='story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a', language=Language.make(language='cmn', territory='CN'), text='早上好，萨姆！今天外面很冷。', text_lower='早上好，萨姆！今天外面很冷。', tokens=['早上', '好', '，', '萨姆', '！', '今天', '外面', '很冷', '。'], audio={'story': {'normal': PhraseAudio(firestore_collection='phrases', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA52C738F0>, key='story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a', text='早上好，萨姆！今天外面很冷。', file_path='phrases/cmn-CN/audio/story/normal/story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a.mp3', language=Language.make(language='cmn', territory='CN'), context='story', speed='normal', voice_info=VoiceInfo(provider='google', voice_id='cmn-CN-Chirp3-HD-Achernar', language_code='cmn-CN'), duration_seconds=3.984, audio_segment=None, gender='FEMALE')}}, image_file_path='phrases/en-GB/images/story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a.png', image=None), 'en-GB': Translation(firestore_collection='phrases', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA52C50290>, key='story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a', language=Language.make(language='en', territory='GB'), text="Good morning, Sam! It's quite cold outside today.", text_lower="good morning, sam! it's quite cold outside today.", tokens=['Good', 'morning', ',', 'Sam', '!', 'It', "'s", 'quite', 'cold', 'outside', 'today', '.'], audio={}, image_file_path='phrases/en-GB/images/story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a.png', image=None), 'ru-RU': Translation(firestore_collection='phrases', bucket_name='audio-language-trainer-private-content', firestore_database='firephrases', firestore_document_ref=<google.cloud.firestore_v1.document.DocumentReference object at 0x000002AA52C90FE0>, key='story_a_winter_morning_walk_d7b5b3#part_1#0#good_morning_sam_its_quite_cold_outside_today_a4305a', language=Language.make(language='ru', territory='RU'), text='Доброе утро, Сэм! Сегодня на улице довольно холодно.', text_lower='добро ...

# %%
for story in all_stories:
    for tag, published_story in story.published.items():
        source_language = published_story.source_language
        target_language = published_story.target_language
        story.publish_story(target_language, source_language, overwrite=True)
