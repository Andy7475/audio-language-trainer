# %%
# %load_ext autoreload

# %%
# %autoreload 2
from dotenv import load_dotenv
import importlib
import sys
import os
import pickle
from pathlib import Path
load_dotenv()
# Add the parent directory of 'src' to the Python path
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

    
from src.config_loader import config, VoiceManager
from src.phrase import generate_phrases_with_llm, generate_phrases_from_vocab_dict, generate_scenario_phrases, generate_scenario_vocab_building_phrases
from src.utils import (load_json, create_test_story_dict, anthropic_generate, save_text_file,
load_text_file, save_json, load_json, load_pickle)
from src.convert import clean_filename
from src.gcs_storage import upload_to_gcs, get_phrase_path, get_phrase_index_path, read_from_gcs, get_phrase_to_story_index_path, get_story_collection_path, get_story_dialogue_path
from src.anki_tools import AnkiCollectionReader, export_to_anki_with_images, get_deck_contents
from src.dialogue_generation import get_story_prompt, generate_story
from src.config_loader import config, VoiceManager, VoiceInfo, VoiceType, VoiceProvider
from src.generate import add_audio, add_translations
from src.nlp import plot_vocabulary_growth, calculate_new_words
from pprint import pprint
import random
import os

# %% [markdown]
# ## Sorting stories
#
# We need to now get stories from the story collection path and refer to the phrase.json and index.json files in order to help sort them

# %%
from src.gcs_storage import get_phrase_index_path, get_story_index_path

story_phrases = read_from_gcs(config.GCS_PRIVATE_BUCKET, get_story_collection_path(collection="LM1000"))
LM1000_phrases = read_from_gcs(config.GCS_PRIVATE_BUCKET, get_phrase_path(collection="LM1000"))
phrase_index = read_from_gcs(config.GCS_PRIVATE_BUCKET, get_phrase_index_path(collection="LM1000"))
story_index = read_from_gcs(config.GCS_PRIVATE_BUCKET, get_story_index_path(collection="LM1000"))

# %%
phrase_index['phrases']
# Out:
# ['Do you want to become a famous writer?',
#  'Let me show you around the city',
#  'We need to handle this situation carefully',
#  'Stop wasting time on this',
#  'Do you like playing the guitar at night?',
#  "I'm taking a vacation next month",
#  "Don't forget to wear a helmet while cycling",
#  "Let's cut unnecessary expenses this year",
#  "We're producing a new product soon",
#  'Did you remember to turn off the stove?',
#  'You have to accept the consequences of your actions',
#  "I just can't understand this complex math problem",
#  "Let's throw a surprise party for mom",
#  'Pay more attention to details',
#  "Don't try to lift heavy furniture alone",
#  'I want to live in a quiet neighborhood',
#  'Please answer all questions honestly',
#  "We're going to run the company efficiently",
#  "Do you think they'll reach their goals soon?",
#  'I should have chosen a different career path',
#  'Do you like collecting seashells at the beach?',
#  "Don't worry, I'll remind you about the meeting tomorrow",
#  'Will the customer recognize me?',
#  'Did you hear the conversation through the thin wall?',
#  'I learned to sing in front of everybody',
#  "Would you eat the fish if it's fresh?",
#  "Did the minister really support the community's interests?",
#  'Shall we help organize the sale next week?',
#  'They found a dead body behind the club',
#  "I tend to forget people's names, it's so embarrassing",
#  'Are they going to teach us how to apply makeup?',
#  'Stop trying to carry the weight of the world',
#  'Should we move to another location?',
#  "I bet you can't fit through that hole",
#  'Did they offer you a reasonable salary for the position?',
#  'I want to read more books this year',
#  "Do you think we'll get a response by tomorrow?",
#  "I can't remember where I left my keys",
#  'Look at that animal dragging itself across the field',
#  'She will call you as soon as possible',
#  'We shared our food with the homeless guy',
#  "Did you hear they're shutting down the factory next month?",
#  'I wished to join the army years ago',
#  'Try to rid yourself of negative thoughts',
#  'Do you walk through the park every evening?',
#  'Have you seen the video about preparing this meal?',
#  'I opened the letter with shaking hands',
#  'I excused myself from the boring conversation',
#  'Let me tell you the story of our journey',
#  "I can't wait to see my daughter at the airport",
#  "Let's thank dad for his useful advice",
#  'The teacher will mention your good work today',
#  'They kept cooking even in this terrible weather',
#  "He might lose his job if he's late",
#  'We really need to cut back on spending this month',
#  'The traffic will be terrible for drivers during the holiday',
#  'I need to read this important letter right away',
#  'Did you enjoy the beautiful garden this afternoon?',
#  'She might forget to bring her lunch today',
#  'Which movie should we watch?',
#  "Don't the kids just love singing in the rain?",
#  "He's going to build us a proper table",
#  "Did you hear they're spending their holiday down south?",
#  "I'm planning to organize the office party soon",
#  "She couldn't afford the expensive birthday gift unfortunately",
#  "She's writing a letter to the local newspaper",
#  'Have you heard? They joined the football team yesterday',
#  "He's planning to grow vegetables in his garden",
#  "Let's compare prices before we decide",
#  "She'll get that phone call from work",
#  "They're shutting the shop early today",
#  'He might draw a picture of the village',
#  "We've got to find a solution to this problem",
#  "She's starting her new job next week",
#  'Did you know they moved to the countryside last year?',
#  "He's trying to improve his cooking",
#  "Let's check the weather forecast today",
#  'She might show us her art collection soon',
#  "Guess what? They're moving to a different city",
#  "He's picking up the kids from school",
#  "We've got to save up for our holiday",
#  "She'd like to share her experience with us",
#  "Have you heard? They're building a house near the sea",
#  'He might offer to help with the work',
#  "Let's keep our options open for now",
#  "She'll ring the doorbell when she gets here",
#  "They're turning off the lights early",
#  "He's trying to learn French",
#  "Let's sort out this mess quickly",
#  'She might imagine a better future for herself',
#  'They decided to eat at the local restaurant',
#  'Press the red button to start',
#  "Let's not worry so much about small things",
#  "She's planning to apply for a new job soon",
#  "Did you hear they're closing the shop for renovations?",
#  'He might charge his phone before leaving',
#  'Sometimes we just need to mind our own business',
#  "She's letting the children play outside",
#  "They've started growing their own vegetables",
#  "He's thinking of referring a friend for the job",
#  'Have you noticed how many more participants there are now?',
#  "She's likely to arrive at any moment now.",
#  "Don't you think this is pretty ordinary?",
#  "Don't tell anyone about this - it's absolutely secret!",
#  'Shall we head to the meeting now?',
#  'The total cost is a bit higher than we thought.',
#  'Hi there! How are you doing this morning?',
#  'Bye for now, see you later this evening!',
#  "Don't you think being together is what matters most?",
#  'Should we rethink our initial plan, everyone?',
#  "Don't worry, you'll get used to the new system.",
#  'Shall we move on to something else?',
#  'Do you know what factors affect our success rate?',
#  'Does this example help clarify things?',
#  "Ok, let's review the list one more time.",
#  "I'm afraid there's no easy solution to this.",
#  "We must ensure everyone's safety first.",
#  "We need to act now or we'll lose everything!",
#  'Are they out of their mind saying that?',
#  "I've never seen anything like this!",
#  "It's a quarter past nine - we're late!",
#  "I'll be at the event myself.",
#  'Mine is the red one on the table.',
#  'Who really knows what the future holds?',
#  'Then again, anything is possible these days, right?',
#  "We don't care if it's a boy or girl.",
#  "Let's hope we get lucky with this!",
#  'I used to think differently about this issue.',
#  'Do you think it could still happen, even if it seems unlikely?',
#  'You need two people to lift anything over fifty pounds.',
#  'Ever wonder why things happen the way they do?',
#  "Anyway, let's get back to the main point.",
#  'Still, I think we should give it a try.',
#  "Whatever happens, we'll face it together, my son.",
#  "Don't you think unity is crucial right now?",
#  'Be prepared - the actual results might be different.',
#  'Could the best solution be right in front of us?',
#  "Instead of complaining, let's find a solution together.",
#  'Can you lend me a buck fifty until payday?',
#  'We all make typing mistakes - even me!',
#  "Don't forget to round up the cost to the nearest cent.",
#  'Are you joining our community cleanup event?',
#  "Let's provide better service to our customers",
#  'I want to live in a different country',
#  "Do you think we'll reach our fitness goals?",
#  'Shall we take a tour around the city?',
#  "Stop making excuses and let's start working",
#  "We're selling our old car soon",
#  "Let's train new employees more effectively",
#  'I want to produce a hit song',
#  'How do you maintain work-life balance?',
#  'Can you teach us how to meditate?',
#  "Let's think outside the box more often",
#  'Want to go on a camping trip?',
#  "God, I'm afraid nobody's totally honest these days.",
#  'Both mummy and daddy are concerned about tax.',
#  'Do you think we can control the situation?',
#  "The operation was serious, but she's all right.",
#  "Act now, before it's too late!",
#  "I'm sorry, but that's simply not good enough.",
#  "I'll definitely note your concerns about this.",
#  "Yes, I'm sure it's worth at least a pound.",
#  "No one else can do it; it's yours.",
#  'I was careful not to show my fear.',
#  'Even a low rate is better than nothing.',
#  'Is this space wide enough for us?',
#  "I'm nearly done with this particular task, honestly.",
#  "Shouldn't we consider other options too?",
#  "The firm's method is completely different than ours.",
#  'Have you already thought about this a lot?',
#  'The level of difficulty is pretty low.',
#  'Should we start from the beginning again?',
#  'The death toll is particularly high this year.',
#  "Normally, I'd say yes, but not this time.",
#  "Of course, there's always room for improvement, right?",
#  "Why don't we use examples? It's the easiest way.",
#  "Don't you think it's a good idea?",
#  "Yeah, I'm totally fine with that, no problem.",
#  'Suddenly, it all became clear as a sheet.',
#  'Only a single line separates success from failure.',
#  "Actually, I'd rather not discuss it, if possible.",
#  'Yep, that sounds like a great plan to me.',
#  "Although it's similar, there are some key differences.",
#  'Shall we think of something else?',
#  'Check with somebody before making any decisions!',
#  "Have you noticed how much the region's air quality has improved?",
#  "I'm certain this is the right way forward.",
#  'Plenty of people have tried, but with little success.',
#  "Whether you like it or not, it's happening.",
#  'Did you hear his arm was injured during the operation?',
#  "Isn't it surprising how the movement has gained momentum?",
#  'Are you training new staff next month?',
#  'I want to produce a documentary film',
#  "Let's look into this matter carefully",
#  'We need to fight for our rights',
#  "I'm teaching English to foreign students",
#  "Let's cover all aspects of the problem",
#  "I'm trying to stick to my diet plan",
#  "Do you think we'll achieve our goals soon?",
#  'I want to wear something special for the occasion',
#  "Let's think about this more carefully",
#  "We're going on vacation next month",
#  'I tried to hit the target but missed',
#  "Let's prepare for any possible outcome",
#  'I want to listen to different opinions first',
#  'Are you coming to her birthday party?',
#  'I hope to graduate from college soon',
#  "Let's choose our words more carefully",
#  "Did you hear they're building a new community center?",
#  'I tried to catch up with the others',
#  'We need to finish this project by Friday',
#  'I want to enhance my public speaking skills',
#  "Do you think we'll achieve our sales targets?",
#  "I'm teaching the new employees tomorrow",
#  "Let's mention this in the meeting",
#  'Are you joining the charity event?',
#  'I knocked on the wrong door',
#  "Let's provide more information to the public",
#  'I want to live a more balanced life',
#  'Can you show me how it works?',
#  "Let's stop worrying about small things",
#  'Are you selling your house next year?',
#  "Let's train harder to win the competition",
#  'I want to produce high-quality content regularly',
#  "Do you think we'll achieve our dreams someday?",
#  'Can you teach me how to cook?',
#  "Let's think twice before making decisions",
#  "We're planning a world tour",
#  'I tried to hit the ball but missed',
#  "Let's prepare for the worst scenario",
#  'I want to listen to different perspectives first',
#  "We're throwing a surprise party for him",
#  'I hope to graduate with honors next year',
#  'Choose your friends wisely',
#  'Did you hear about the new shopping center?',
#  'I tried to catch the last bus home',
#  "Let's finish our homework before dinner",
#  'I want to enhance my leadership skills',
#  "Do you think we'll achieve financial independence soon?",
#  'Can you teach me how to dance?',
#  "Let's mention this to our boss",
#  "Sorry I'm late to the meeting",
#  'Did they enter the building through the back door?',
#  'What happened to your old car?',
#  "The concert starts at eight o'clock",
#  'This cake tastes absolutely delicious',
#  'I love cooking Italian food',
#  "Didn't she sing beautifully at the wedding?",
#  "We still haven't resolved this issue",
#  "Don't bother calling, I'll be busy",
#  "Let's sit down and discuss this calmly",
#  "I'm so excited about our upcoming vacation",
#  "Don't you think they worry too much about small things?",
#  'Shall we try that restaurant?',
#  'Make sure to double-check your work',
#  'We really need to reduce our carbon footprint',
#  'Could you close the curtains before you leave?',
#  'I care deeply about environmental issues',
#  "Don't forget to set your alarm for six",
#  "Let's teach the members how to dive carefully",
#  "Don't they bear the burden of society's expectations?",
#  'I really want to achieve more in my career',
#  "She'll catch a cold in this weather",
#  'Are you preparing the stage for the occasion?',
#  'Have they shared their suggestion with management?',
#  'Can you show me how to organize this?',
#  'We need to finish the project by Friday',
#  'Are they hoping to graduate with honors next year?',
#  'She ran to catch the last train home',
#  "Don't you think the character is well-developed?",
#  "I'll tell you the real reason later",
#  'They just want a chance to prove themselves',
#  "Let's base our decision on facts",
#  'He tried to knock some sense into them',
#  "They're building a new union headquarters soon",
#  "She's trying to enhance her skills at work",
#  'When should we schedule the meeting?',
#  'Did they really see a UFO?',
#  "He's receiving an award for his work",
#  "Let's stop wasting time on this",
#  'They sold all their tickets',
#  "She's planning to move to the west coast",
#  'We have to reach an agreement by tomorrow',
#  'He realized his mistake too late',
#  'Are they providing food for the event?',
#  'She really wants to serve her community better',
#  "Shouldn't we mention this to the others?",
#  "They're keeping the matter private",
#  "He's thinking of changing his work schedule",
#  'We need to collect the data by next week',
#  "She's trying to break her bad habits",
#  'Please arrive by noon',
#  'Does it really matter in the long run?',
#  'Could you send me that information by email?',
#  "Let's meet at the usual place tonight",
#  'Just use your common sense here',
#  'I wonder what the future holds for us',
#  'Keep working until you finish the job',
#  'Can you imagine a world without technology?',
#  'Drive carefully on your way home, dear',
#  'Could you cut the cake into equal pieces?',
#  "Don't forget to feed the dog before you leave",
#  'Just follow the instructions step by step',
#  'What does this sentence actually mean?',
#  'Would you like to join us for dinner?',
#  'Everyone seems to be stressed these days',
#  "I know exactly what you're talking about",
#  'Did you hear? They won the big contract!',
#  "Let's sort this mess out once and for all",
#  "I'm sure our team will win tomorrow",
#  "Why won't anyone help?",
#  "She's loved art since she was little",
#  'How do you deal with difficult customers?',
#  'We need to raise awareness about this',
#  "I can't remember where I put my keys",
#  'Would you mind closing the window, please?',
#  'He passed away peacefully in his sleep',
#  'Should we order takeout for dinner tonight?',
#  'Just say what you mean',
#  'I want to learn a new language this year',
#  'Can I share my thoughts on this?',
#  'How much does this service usually cost?',
#  'Can you fix this problem by tomorrow?',
#  "I'm here to help in any way I can",
#  'Did you hear about the latest news?',
#  "We can't make any mistakes now",
#  'How do you handle stress at work?',
#  "Don't forget to bring your own food to the picnic",
#  'You should write down your ideas before you forget',
#  "I accept your apology, let's move on",
#  'They play football every Sunday afternoon',
#  'Excuse me, could you explain that again?',
#  "We're planning to visit Rome next summer",
#  "Let's talk about something more interesting",
#  "Don't forget to pay the bills on time",
#  'Did you notice he referenced that book in his speech?',
#  'Just stay calm - everything will be fine',
#  'Thank goodness nobody was hurt in the accident',
#  'Make sure you consider all your options first',
#  "I'll get back to your email as soon as I can",
#  'Are you ready for the party tonight?',
#  'Hold on tight, the ride is starting',
#  'Do you train hard to improve your skills?',
#  "Don't worry, everything will be fine",
#  'Speak up if you have any concerns',
#  "I can't figure out this puzzle yet",
#  'The show starts in five minutes',
#  'That seems like a good idea',
#  'Have you considered the consequences?',
#  'Did you hear? The car hit a tree',
#  'We should discuss this issue more',
#  'Press the button to call the elevator',
#  "Look! The eagle's diving for its prey",
#  "Let's deal with this problem right away",
#  'Are you fighting for equal rights and justice?',
#  'Hang the coat on the rack, thanks',
#  "Don't forget to send the email before leaving work",
#  'Shall we build a better future together?',
#  'I cook delicious meals every day',
#  'Close the door when you leave, okay?',
#  "I always forget what's going on",
#  'They just explained the budget system to me',
#  'Shall we meet at the east side?',
#  "Let's talk about the language of love",
#  'Did she forget to pay for the service?',
#  'Remember that specific case I mentioned?',
#  'Stay aware of your surroundings at night',
#  'Nobody got hurt in the accident, just the car',
#  'Have you considered all your options?',
#  "I'll answer your questions soon",
#  'Are you ready for the big event tomorrow?',
#  "Sorry, I'm really tired right now",
#  'Did they get into the site okay?',
#  'What happened to the rest of the cake?',
#  'The meeting starts at half past',
#  'This soup tastes nothing like the original',
#  'I cook special meals for my husband',
#  'Did you hear her sing about love and loss?',
#  "We still haven't solved the problem",
#  'Wash your hands before you eat, please',
#  "Don't bother me with such trivial matters",
#  "Let's sit and discuss this over tea",
#  "I'm so happy for you",
#  "Don't strange things happen in the middle of nowhere?",
#  'Are you worried about the economy?',
#  'I suppose we should leave now, right?',
#  'Make your own choice in this matter',
#  'We need to cut back on spending this month',
#  'Please close the door on your way out',
#  'I care about you, my friend',
#  'Set the table for dinner, would you?',
#  'Look at that bird diving into the clear water!',
#  "Let's deal with this issue right now",
#  'Are they fighting for justice in the court?',
#  'Lay the clothes on the bed, please',
#  'Could you hang the picture on the bedroom wall?',
#  'Send the package as soon as possible',
#  "We're building a new house next year",
#  "Don't you love how she cooks wonderful meals for her family?",
#  "Close the window, it's getting cold outside",
#  'Wait for me at the bus stop',
#  'Fill the glass with water, would you?',
#  'Can you explain this concept to me?',
#  'It depends on the weather, obviously',
#  'How long will this meeting last?',
#  "I don't know the answer to that",
#  'Watch the ball roll down the hill!',
#  'Clear your mind before you begin',
#  'Drive carefully on the icy roads',
#  'Decide what you want for dinner',
#  'I was born in a small town',
#  'Use the glue to make it stick firmly',
#  'When did you arrive at the airport?',
#  'Finish your homework before watching TV',
#  'Stand up straight and look ahead',
#  'Can you manage this project by yourself?',
#  'Just follow the signs to reach your destination',
#  'Ask for help if you need it',
#  'Can you imagine a world without any troubles?',
#  'Pull the lever to start the machine',
#  "Don't shoot! It's just a game",
#  'I love listening to music while cooking dinner',
#  "Let's compare the prices of different cars",
#  'Do you care about the environment?',
#  'I love to read books in my bedroom',
#  'I achieved my dreams through hard work',
#  "Put your coat on, it's cold outside",
#  'Can we afford to go on vacation?',
#  'Look at that beautiful sunset over there',
#  'Wash your hands with soap and water',
#  'Did you draw a picture of your family?',
#  'This accident is causing a major traffic jam',
#  "Knock before entering, it's common courtesy",
#  "I feel happy when I'm with you",
#  'Shall we dive into the pool together?',
#  'Mind the gap between the train and the platform',
#  'You should reduce your sugar intake for better health',
#  'Keep your promises, it builds trust',
#  "Don't lose hope, better days are ahead",
#  'Add some salt to enhance the flavor',
#  "Don't worry, the alarm will sound if there's danger",
#  'Did you hear about the assassination attempt on the president?',
#  "This shirt doesn't fit me anymore",
#  'Should we take a different route?',
#  "I can't remember where I parked my car",
#  'Is she really an expert in the field?',
#  "Don't you think it's time for a change?",
#  'Did he really change his mind at the last moment?',
#  "I bet she won't show up tonight",
#  'Have you seen the feast they prepared for the wedding?',
#  'We wish you the best of luck',
#  "Let's dive into the pool to cool off",
#  'Should we excuse ourselves from this boring party?',
#  'Tell us about your adventures abroad',
#  'Can you believe they ate the entire cake by themselves?',
#  'I think we should leave now',
#  "I'm expecting to graduate next spring",
#  'I meant to call but forgot',
#  'We watched the sunrise over the mountains',
#  'I hurt my ankle while playing tennis',
#  'Listen to the wonderful sound of nature',
#  "Let's compare the size of our profits",
#  "Do you care about the public's opinion?",
#  'Do you love cooking in your bedroom?',
#  'I achieved my goals within three months',
#  'Put the paper on the board, please',
#  'Can you afford to buy a house?',
#  'Look at the clear sky up north',
#  'Wash your hands before you cook, okay?',
#  'I drew a picture of the land',
#  'Did you hear about the noise causing trouble in the neighborhood?',
#  'Knock on the door before you enter',
#  'I feel sick after eating that stuff',
#  'Shall we dive underwater to explore the reef?',
#  'Mind your own business, young man',
#  'Reduce your speed in this area, please',
#  'Keep your eyes on the road ahead',
#  "Don't lose hope in difficult times, sir",
#  'Add some spice to make it taste',
#  "The alarm will sound at six o'clock",
#  "Hold onto the rail, it's slippery",
#  'Do you train every day to achieve success?',
#  "Don't worry about the small stuff, honey",
#  'Speak clearly when you give directions',
#  "I can't figure out this math problem",
#  'The meeting will begin at noon sharp',
#  'It seems like a normal day so far',
#  'Consider your options before making a decision',
#  'Did the ball hit the window by accident?',
#  'We need to talk about our relationship',
#  'Press the button to start the process',
#  "Let's go to bed early so we feel better tomorrow",
#  "Do you think she'll become a famous artist one day?",
#  'Did you hear they pulled out of the competition?',
#  "He's going to show us around the new office",
#  'We have to pass this exam to graduate',
#  'I want to continue my studies abroad',
#  'Did you like their Facebook page yesterday?',
#  "Do you think he'll enjoy the concert tonight?",
#  'Love your neighbors as yourself',
#  'I need to cost this project before starting it',
#  "We're keeping the old furniture for now",
#  'Can you guess the answer to this question?',
#  'I should phone the doctor for an appointment',
#  'Should we include everyone in the plan?',
#  'We brought cake to the party',
#  "Don't forget to stamp the letter before mailing it",
#  "Let's work hard to achieve our goals",
#  'I want to answer all these questions correctly',
#  'We had to put the meeting on hold',
#  'He might mention your name in the report',
#  'We have to tell the truth about what happened',
#  "I'll start the car and drive home",
#  'Shall we pick some flowers from the garden?',
#  'I just want to sit quietly and read my book',
#  "Let's share our food with those in need",
#  "Do you think she'll start her speech with a joke?",
#  "We're going to sing at the local concert",
#  "I'm moving to a new apartment next month",
#  'You have to face your fears to grow stronger',
#  'I just want to feel happy and content',
#  'Remember to speak softly in the library',
#  'Are you going to sleep late this weekend?',
#  "Let's press for better working conditions",
#  "I'll have the report ready by next week",
#  "Did you hear they're allowing pets in the building now?",
#  "Don't forget to charge your electric car overnight",
#  'You should eat more vegetables to stay healthy',
#  'Shall we plan a surprise party for mom?',
#  'The children are playing outside',
#  "I'll draw you a map to the new office",
#  "Let's try to walk more and drive less",
#  'I want to live in a big city someday',
#  'Shall we cook dinner together tonight?',
#  'He sounds excited about the new project',
#  'Always compare prices before buying anything',
#  'I like to listen to music while working out',
#  'Pull the car over safely',
#  'I want to show my artwork at the gallery',
#  "Let's share the good news right away",
#  'Would you like me to fill your cup with tea?',
#  "Wasn't that film absolutely amazing?",
#  'She watched the sunset from her balcony',
#  'Did you hear? He hurt himself fixing the roof',
#  'Quick, help me carry this injured person to safety',
#  'Thank you so much for your kind gesture',
#  'Our waiter is so friendly, serving us with a smile',
#  "They're letting us enter the building now",
#  'This trip is going to cost us a pretty penny',
#  "Let's share our concerns with the panel",
#  'I just got a message from my father',
#  'Did you join the protest against high taxes?',
#  'I need to get rid of this old furniture',
#  "Let's walk to work to save money",
#  'Do you support these new environmental laws?',
#  'I wonder if that rumor is true',
#  'Did you hear about the accident on the busy street?',
#  'She works hard to provide for her family',
#  'Many soldiers died defending their country',
#  "I'm writing a letter to my local minister",
#  "Aren't you enjoying our vacation by the sea?",
#  'She always brings up her ex in conversations',
#  "Don't worry about what others think of you",
#  "I'm trying to dry my clothes in the sun",
#  'Shall we go to the park to feed the ducks?',
#  "I'm letting my hair grow long and wild",
#  'Are you planning to expand your business next year?',
#  'You need excellent communication skills for this job',
#  'Did you phone your mother to say hello?',
#  "Let's help this elderly person cross the street",
#  'Do you check your account balance every day?',
#  'I suppose we could try it your way',
#  "Let's try to sort out our differences",
#  'I want to lead the team to victory',
#  'Are you going to the science lecture tomorrow?',
#  'It might rain later, bring an umbrella',
#  'Did you hear him cough during the quiet moment?',
#  'We just moved to a new house last month',
#  'Do you believe in ghosts and supernatural phenomena?',
#  'I sang a lullaby to my baby sister',
#  'Remember, honesty is the best policy',
#  'Did you learn about different cultures in school?',
#  'I recognized her voice on the phone right away',
#  'Have you applied for a loan at the bank?',
#  'Do you read bedtime stories to your children?',
#  "Let's call for help - the car broke down",
#  'Cover your face with your hands',
#  'Did you hear? They passed the test with flying colors!',
#  'Could you help me set the table for dinner guests?',
#  'Shall we help with the cleanup?',
#  "Don't you hate waking up early in the morning?",
#  'Can you believe they won the game against all odds?',
#  'I suffered a heavy loss at the bank',
#  'Can you manage the office until tonight?',
#  'Push the door open with your free hand',
#  'I suppose the meeting will end soon',
#  'Do you collect old bottles as a hobby?',
#  'Did you see the dog catch the ball in midair?',
#  'Could you explain the difference between these rules?',
#  'We train every day to win the cup',
#  'Do you support the new regional development programme?',
#  'This feeling of success will stay with you',
#  'Wash your hands before you drink tea',
#  'Check the file for any recent changes',
#  "They're laying the foundation for a new hospital",
#  'Change your shirt before the important meeting',
#  "Let's talk about the opportunity over coffee",
#  'Shall we take a quick break?',
#  'Did you hear someone knock on the door late at night?',
#  'Did you see the new film last week?',
#  'Clean the floor before the guests arrive',
#  'Look at those two boys fighting over a toy car',
#  "I bet you can't eat the whole cake",
#  'This situation is hard to understand',
#  "Don't forget to water the plant or it will die",
#  'Cover your mouth when you cough, please',
#  'Look at the beautiful view from here',
#  'Have you considered the long-term effects of your decision?',
#  'What did you say to him yesterday?',
#  'All this pressure at work is causing me stress',
#  'Do you know the way to the hospital?',
#  'When will the package come in the mail?',
#  'I care about the quality of education',
#  'Call me if you need any help',
#  'What do you mean by that statement?',
#  'What will you do with your free time?',
#  "The movie's about to end",
#  'Raise your hand if you have a question',
#  'Stand up straight when you give your speech',
#  "They're getting married in the spring",
#  'Ask your parents for their opinion first',
#  "Don't bother him while he's working",
#  'The rain should stop soon',
#  'Be careful - the glass will break if you drop it',
#  "Don't forget your passport for the trip",
#  'I hope the weather will be nice tomorrow',
#  'Do you agree with the new company policy?',
#  "Let's drink to our success tonight",
#  "What will happen if we're late?",
#  'Send the application as soon as possible',
#  'The car stops at the next station',
#  "I wonder what's for dinner tonight",
#  'Can you carry this heavy bag for me?',
#  'Excuse me, where is the nearest bank?',
#  "Don't forget to feed the dog tonight",
#  'Will you accept my apology for being late?',
#  'Does the hotel provide breakfast in the morning?',
#  "It all depends on tomorrow's test results",
#  'Can you hang the wet clothes out to dry?',
#  'Cut the cake into equal pieces, please',
#  'Wait for me at the bottom of the stairs',
#  'Use this bottle to carry your water',
#  'Follow the road until you reach the bridge',
#  'Do you think the product is entirely safe?',
#  'Does it matter what color we choose?',
#  'Who will teach the class next week?',
#  'Did you see the ball hit the wall and bounce back?',
#  'Roll the dice to see who goes first',
#  'I just realized I forgot my keys',
#  'Do you understand the main idea here?',
#  'Think carefully before making your final decision',
#  'Can you figure out this math problem?',
#  'I recognize that man from somewhere',
#  'Take your time answering the question',
#  "Let's get rid of these old newspapers",
#  'The meeting starts in five minutes',
#  'Could you fill in this form with your personal details?',
#  'Did you hear she won an award for her scientific research?',
#  'Have you heard the company suffered significant financial losses?',
#  'How do you manage your time so efficiently?',
#  'Push the red button to start the machine',
#  'I suppose we should leave early tomorrow',
#  'Did you know he collects rare coins as a hobby?',
#  'Did you hear the police caught the thief last night?',
#  'Can you explain this chart to me?',
#  'Are they training hard for the upcoming competition?',
#  'We should support local businesses more often',
#  'Have you heard the old building is closed for renovation?',
#  'Wash your hands before handling food',
#  "Don't forget to check your emails in the morning",
#  'Could you lay the table for dinner, please?',
#  'Do you think the weather might change later today?',
#  "Let's talk about our holiday plans",
#  'I suggest we try the new restaurant',
#  'Did you hear someone knock at the door past midnight?',
#  'Did you see that shooting star?',
#  'Clean your room before going out',
#  'Are you watching the two teams fight for first place?',
#  'I bet it will rain this weekend',
#  "Don't you think the solution seems quite simple?",
#  'Did you see the blue chair fall across the large room?',
#  'Is your brother really going to run towards hell?',
#  'Did you see the lovely egg she made for her mum?',
#  'The coffee at the national park was excellent',
#  'Do you want to buy his hat?',
#  'Did you see that stupid comment on Twitter?',
#  "Let's have the meeting in the central office",
#  'I need extra time to finish my homework',
#  'Have you been to that new bar in the centre?',
#  "I'm just killing time reading these books about nature",
#  'That young girl is determined to succeed',
#  'I hate missing the bus in summer',
#  'Did you get a fair deal on your car?',
#  'Look how fast that black horse runs!',
#  "Don't forget to pay the gas bill",
#  'Did you see his funny hat at the party?',
#  'That short man can throw the ball really far!',
#  'Remember when we met at the coffee shop last week?',
#  "Don't you think the price is too high?",
#  'I was born in a small country town',
#  'Look at the fresh flowers she put in each room',
#  'Did you hurt your leg during the football game?',
#  'The show lasted for an hour and half',
#  "We're staying at this lovely hotel by the sea",
#  'He cleared his throat before the speech began',
#  'Did you hear about the accident on the busy street corner?',
#  'I based my decision on previous experience',
#  'Just throw the old computer in the trash',
#  'Did you hear that strange noise from upstairs?',
#  "These new shoes don't fit my feet properly",
#  'He paid a high price for his mistake',
#  "Look how the sun's clearing away the morning fog",
#  'Did you see her green dress at the party?',
#  "Let's deal with this problem in private",
#  'Did you see how he led the team to victory last night?',
#  'Would you like me to serve coffee to the guests?',
#  "Don't you believe in the power of positive thinking?",
#  'Hold onto the railing for dear life!',
#  "I'm preparing a delicious meal for my family",
#  'Should we stick to our original plan despite the doubts?',
#  'Do you need help with your homework assignment?',
#  'Open your heart to new possibilities',
#  'Did you hear they set a new record in the race?',
#  'Did you notice her beautiful smile across the room?',
#  'I based my argument on scientific facts',
#  "Let's throw a surprise party for mom!",
#  "Don't forget to be on time",
#  'I hate the taste of brussels sprouts',
#  'We received such a warm welcome at the airport',
#  'Did you know he met his wife at a social event?',
#  "Don't you think it's time for a change?",
#  "Let's make a wish upon a star tonight",
#  'Did you know he was born into a wealthy family?',
#  'Add some spice to make the dish tastier',
#  'We missed the train by five minutes!',
#  'I hurt my back lifting those heavy boxes',
#  "Don't you think this movie is dragging on forever?",
#  'Have you finished your homework before dinner?',
#  'I keep falling asleep during this boring lecture',
#  'Did you hear that lovely bird song this morning?',
#  'This dress fits me like a glove!',
#  'Make sure to pay attention to every little detail',
#  'Could you clear the table after dinner?',
#  "Don't you think strange things happen in that old house?",
#  'I run a mile every morning before work',
#  'Did you see how she led the discussion with such enthusiasm?',
#  'Shall we serve breakfast in bed this Sunday?',
#  'Deal the cards quickly and efficiently',
#  'Do you believe in ghosts and supernatural phenomena?',
#  'Hold your breath as you dive underwater',
#  "I'm preparing for the worst but hoping for the best",
#  "Don't stick your tongue out at your brother!",
#  'Everyone must wear a mask inside',
#  'Have you chosen a white church for the wedding?',
#  "I'm graduating from college next term!",
#  'Did you hear they got married on a boat in this hot weather?',
#  'Are you trying to sell that radio at the market?',
#  'How did I miss noticing that huge fire?',
#  'Did you see the cat bounce off the kitchen window?',
#  'Feel free to pick any tree in this area',
#  'Shall we drink our coffee on the ground?',
#  'Did you forget to include the data in the report?',
#  'Have you been wearing the same shirt since then?',
#  'The army officer must face the enemy soon',
#  'I hope to win the contract this week',
#  "I can't handle this awful heat anymore!",
#  "Let's refer to the second copy",
#  'Are they still going to produce cheap materials?',
#  'I was born in a small fishing village',
#  'The company will charge a fair amount',
#  "Don't forget to ring the church bell!",
#  'Push the button to answer',
#  'Shall we collect interesting rocks along the beach?',
#  "We'll have to stay home because of the rain",
#  'Oh no, I dropped the glass and it broke!',
#  'Do you like playing with your pet cat?',
#  'Let me talk to the manager about this',
#  "Don't forget to cut your hair before the interview",
#  "Let's find a solution to this issue",
#  'Shall we meet at the store?',
#  'I want to buy a new television set',
#  "Don't forget to bring the ticket",
#  "I can't understand why he did that",
#  "Shouldn't we spend more time with family?",
#  'Stop the production immediately',
#  'Would you show us around the college campus?',
#  'She tried to lift the heavy box herself',
#  'Feel free to sit anywhere in this section',
#  "Let's base our decision on the data",
#  "Do you think they'll reach an agreement soon?",
#  'Did you forget to pay the electricity bill?',
#  'You need to accept the job offer today',
#  "I'm taking the dog for a walk",
#  "Shouldn't we try to save some money?",
#  'Are you coming to the party next weekend?',
#  'He tried to catch the falling glass',
#  'I want to live in a modern city',
#  'Turn off the radio, please',
#  'Want to run a marathon for charity?',
#  'Stay calm during the interview',
#  'Do you play golf on weekends?',
#  "I'll call you back later",
#  'I need to find my lost ticket',
#  "Let's use this material for the project",
#  "Don't lie again, or you'll suffer",
#  'You should have chosen a different color',
#  'I want to become a famous actress',
#  "Don't forget to stamp these envelopes",
#  'The meeting ends at noon',
#  'Show more respect to elders',
#  'Did you try to guess the correct answer?',
#  "I'll keep bothering you until you agree",
#  'This noise is keeping me awake',
#  "Let's face our fears to succeed",
#  'Are you coming to the party tonight?',
#  'Do you collect rare coins as a hobby?',
#  'You should have realized your mistake earlier',
#  "Stop smoking - it's bad for your health",
#  "Hurry up or we'll miss the train",
#  "Wouldn't it be great to win the lottery?",
#  'Did you forget your license again?',
#  "I'm graduating from university next year",
#  "Let's include everyone in this event",
#  'Shall we pick fresh vegetables for dinner?',
#  'Are you selling your old car soon?',
#  'I want to marry my longtime girlfriend',
#  'Which job offer should I choose?',
#  "Don't forget to drink more water",
#  "Let's base our research on this data",
#  "Wouldn't it be amazing to find buried treasure?",
#  'He tried to catch the falling plate']

# %%
from src.phrase import build_phrase_to_story_index
# Build the index
phrase_to_stories = build_phrase_to_story_index(collection="LM1000")

# Save it to GCS
upload_to_gcs(
    phrase_to_stories,
    bucket_name=config.GCS_PRIVATE_BUCKET,
    file_name=get_phrase_to_story_index_path(collection="LM1000"),
)

# %%
#phrases without a story:

phrases_without_story = []
for phrase in LM1000_phrases:
    if clean_filename(phrase) not in phrase_to_stories:
        phrases_without_story.append(phrase)

# %%
# let's get all story dialogue
from collections import defaultdict

all_story_dialogue = defaultdict(dict)
for story_name in story_phrases:
    story_dialogue = read_from_gcs(config.GCS_PRIVATE_BUCKET, get_story_dialogue_path(story_name, collection="LM1000"))
    all_story_dialogue[story_name] = story_dialogue

# %%
all_story_dialogue.keys()
# Out:
# dict_keys(['story_the_birthday_party', 'story_camping_trip_gone_awry', 'story_a_fishing_trip', 'story_job_interview_gone_wrong', 'story_midnight_garden_mystery', 'story_rainy_football_match', 'story_sunset_wedding_blues', 'story_team_spirit', 'story_winter_in_sweden', 'story_forgetful_diver', 'story_unexpected_career_change', 'story_brussels_blend', 'story_road_trip', 'story_the_marathon', 'story_better_than_a_movie', 'story_teaching_music', 'story_the_power_cut', 'story_a_missed_stop', 'story_unexpected_wedding_guests', 'story_workplace_stress_vacation'])

# %%
from src.gcs_storage import get_story_index_path
from src.nlp import create_story_index

story_index = create_story_index(all_story_dialogue)
# Out:
# Indexing stories...: 100%|██████████| 20/20 [10:08<00:00, 30.43s/it]

# %%
upload_to_gcs(story_index, config.GCS_PRIVATE_BUCKET, get_story_index_path(collection="LM1000"))
# Out:
# 'gs://audio-language-trainer-private-content/collections/LM1000/story_index.json'

# %%
len(story_index['story_vocab']['story_the_birthday_party']['verbs'])
# Out:
# 45

# %%
from src.nlp import assign_phrases_to_stories
assignments = assign_phrases_to_stories(
    phrase_index=phrase_index,
    story_index=story_index,
    max_phrases_per_story=70,
    top_n=5
)
# Out:
# Assignment Statistics:
# Total phrases: 841
#
# Phrases per story:
# story_the_birthday_party: 70 phrases
#   New verbs covered: 101
#   New vocab covered: 245
# story_camping_trip_gone_awry: 70 phrases
#   New verbs covered: 94
#   New vocab covered: 217
# story_a_fishing_trip: 70 phrases
#   New verbs covered: 104
#   New vocab covered: 229
# story_job_interview_gone_wrong: 70 phrases
#   New verbs covered: 107
#   New vocab covered: 216
# story_midnight_garden_mystery: 69 phrases
#   New verbs covered: 100
#   New vocab covered: 222
# story_rainy_football_match: 58 phrases
#   New verbs covered: 87
#   New vocab covered: 193
# story_sunset_wedding_blues: 52 phrases
#   New verbs covered: 84
#   New vocab covered: 171
# story_team_spirit: 40 phrases
#   New verbs covered: 70
#   New vocab covered: 136
# story_winter_in_sweden: 41 phrases
#   New verbs covered: 67
#   New vocab covered: 144
# story_forgetful_diver: 37 phrases
#   New verbs covered: 63
#   New vocab covered: 137
# story_unexpected_career_change: 29 phrases
#   New verbs covered: 48
#   New vocab covered: 114
# story_brussels_blend: 26 phrases
#   New verbs covered: 46
#   New vocab covered: 100
# story_road_trip: 31 phrases
#   New verbs covered: 54
#   New vocab covered: 116
# story_the_marathon: 28 phrases
#   New verbs covered: 51
#   New vocab covered: 103
# story_better_than_a_movie: 28 phrases
#   New verbs covered: 52
#   New vocab covered: 108
# story_teaching_music: 28 phrases
#   New verbs covered: 48
#   New vocab covered: 104
# story_the_power_cut: 25 phrases
#   New verbs covered: 43
#   New vocab covered: 95
# story_a_missed_stop: 23 phrases
#   New verbs covered: 42
#   New vocab covered: 88
# story_unexpected_wedding_guests: 22 phrases
#   New verbs covered: 41
#   New vocab covered: 86
# story_workplace_stress_vacation: 24 phrases
#   New verbs covered: 43
#   New vocab covered: 103

# %%
841/20
# Out:
# 42.05

# %%
from src.nlp import analyze_phrase_story_vocabulary_overlap
analysis = analyze_phrase_story_vocabulary_overlap(
    assignments=assignments,
    story_index=story_index,
    phrase_index=phrase_index,
    collection="LM1000"
)
# Out:
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 60.0%
# Target vocabulary covered by flashcards: 46.3%
#
# Verbs needing new flashcards:
# ['turn', 'cook', 'shop', 'pull', 'call'] ...
#
# Vocabulary needing new flashcards:
# ['happy', 'list', 'birthday', 'mind', 'delicious'] ...
#
# Vocabulary Analysis for story_the_birthday_party:
# Assigned phrases: 70
# Verb coverage: 60.0%
# Vocabulary coverage: 46.3%
# Missing verbs: 18
# Missing vocabulary: 58
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 54.1%
# Target vocabulary covered by flashcards: 44.2%
#
# Verbs needing new flashcards:
# ['pour', 'soak', 'heat', 'wake', "'ve"] ...
#
# Vocabulary needing new flashcards:
# ['unexpected', 'memory', 'sky', 'thank', 'while'] ...
#
# Vocabulary Analysis for story_camping_trip_gone_awry:
# Assigned phrases: 70
# Verb coverage: 54.1%
# Vocabulary coverage: 44.2%
# Missing verbs: 17
# Missing vocabulary: 63
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 72.2%
# Target vocabulary covered by flashcards: 42.1%
#
# Verbs needing new flashcards:
# ['pick', 'lose', "'ve", 'believe', 'pass'] ...
#
# Vocabulary needing new flashcards:
# ['like', 'map', 'good', 'weekend', 'forward'] ...
#
# Vocabulary Analysis for story_a_fishing_trip:
# Assigned phrases: 70
# Verb coverage: 72.2%
# Vocabulary coverage: 42.1%
# Missing verbs: 10
# Missing vocabulary: 62
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 69.2%
# Target vocabulary covered by flashcards: 46.0%
#
# Verbs needing new flashcards:
# ['stumble', 'top', 'enter', 'spill', 'break'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'awful', 'everything', 'perspective', 'definitely'] ...
#
# Vocabulary Analysis for story_job_interview_gone_wrong:
# Assigned phrases: 70
# Verb coverage: 69.2%
# Vocabulary coverage: 46.0%
# Missing verbs: 12
# Missing vocabulary: 54
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 74.3%
# Target vocabulary covered by flashcards: 48.1%
#
# Verbs needing new flashcards:
# ['turn', 'include', 'find', 'work', 'believe'] ...
#
# Vocabulary needing new flashcards:
# ['child', 'yes', 'definitely', 'absolutely', 'potential'] ...
#
# Vocabulary Analysis for story_midnight_garden_mystery:
# Assigned phrases: 69
# Verb coverage: 74.3%
# Vocabulary coverage: 48.1%
# Missing verbs: 9
# Missing vocabulary: 54
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 44.2%
# Target vocabulary covered by flashcards: 45.3%
#
# Verbs needing new flashcards:
# ['pour', 'show', 'adjust', 'focus', 'train'] ...
#
# Vocabulary needing new flashcards:
# ['happy', 'against', 'awful', 'pass', 'muddy'] ...
#
# Vocabulary Analysis for story_rainy_football_match:
# Assigned phrases: 58
# Verb coverage: 44.2%
# Vocabulary coverage: 45.3%
# Missing verbs: 24
# Missing vocabulary: 52
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 54.5%
# Target vocabulary covered by flashcards: 48.8%
#
# Verbs needing new flashcards:
# ["'ve", 'work', 'worry', 'believe', 'marry'] ...
#
# Vocabulary needing new flashcards:
# ['yet', 'relationship', 'inspiring', 'thank', 'everything'] ...
#
# Vocabulary Analysis for story_sunset_wedding_blues:
# Assigned phrases: 52
# Verb coverage: 54.5%
# Vocabulary coverage: 48.8%
# Missing verbs: 15
# Missing vocabulary: 43
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 45.5%
# Target vocabulary covered by flashcards: 47.8%
#
# Verbs needing new flashcards:
# ['bring', 'got', 'visit', 'surround', 'hurt'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'red', 'accident', 'teammate', 'team'] ...
#
# Vocabulary Analysis for story_team_spirit:
# Assigned phrases: 40
# Verb coverage: 45.5%
# Vocabulary coverage: 47.8%
# Missing verbs: 24
# Missing vocabulary: 48
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 48.6%
# Target vocabulary covered by flashcards: 32.7%
#
# Verbs needing new flashcards:
# ['find', 'bring', 'lose', 'visit', 'ask'] ...
#
# Vocabulary needing new flashcards:
# ['winter', 'map', 'delicious', 'thick', 'yes'] ...
#
# Vocabulary Analysis for story_winter_in_sweden:
# Assigned phrases: 41
# Verb coverage: 48.6%
# Vocabulary coverage: 32.7%
# Missing verbs: 19
# Missing vocabulary: 70
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 47.7%
# Target vocabulary covered by flashcards: 33.6%
#
# Verbs needing new flashcards:
# ['leave', 'wake', 'dive', 'enjoy', 'borrow'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'crucial', 'spare', 'sorry', 'hotel'] ...
#
# Vocabulary Analysis for story_forgetful_diver:
# Assigned phrases: 37
# Verb coverage: 47.7%
# Vocabulary coverage: 33.6%
# Missing verbs: 23
# Missing vocabulary: 71
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 41.9%
# Target vocabulary covered by flashcards: 38.2%
#
# Verbs needing new flashcards:
# ['lose', 'handle', 'build', 'buy', 'track'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'yes', 'sorry', 'spirit', 'app'] ...
#
# Vocabulary Analysis for story_unexpected_career_change:
# Assigned phrases: 29
# Verb coverage: 41.9%
# Vocabulary coverage: 38.2%
# Missing verbs: 25
# Missing vocabulary: 63
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 35.9%
# Target vocabulary covered by flashcards: 34.3%
#
# Verbs needing new flashcards:
# ['call', 'order', 'know', 'imagine', 'sound'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'place', 'two', 'while', 'coat'] ...
#
# Vocabulary Analysis for story_brussels_blend:
# Assigned phrases: 26
# Verb coverage: 35.9%
# Vocabulary coverage: 34.3%
# Missing verbs: 25
# Missing vocabulary: 67
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 45.9%
# Target vocabulary covered by flashcards: 30.0%
#
# Verbs needing new flashcards:
# ['compare', 'wake', 'show', 'calm', 'know'] ...
#
# Vocabulary needing new flashcards:
# ['thank', 'america', 'incredible', 'scientific', 'unforgettable'] ...
#
# Vocabulary Analysis for story_road_trip:
# Assigned phrases: 31
# Verb coverage: 45.9%
# Vocabulary coverage: 30.0%
# Missing verbs: 20
# Missing vocabulary: 84
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 37.5%
# Target vocabulary covered by flashcards: 40.4%
#
# Verbs needing new flashcards:
# ['handle', 'disappoint', 'achieve', 'hurt', 'check'] ...
#
# Vocabulary needing new flashcards:
# ['charity', 'runner', 'yet', 'first', 'understanding'] ...
#
# Vocabulary Analysis for story_the_marathon:
# Assigned phrases: 28
# Verb coverage: 37.5%
# Vocabulary coverage: 40.4%
# Missing verbs: 25
# Missing vocabulary: 53
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 33.3%
# Target vocabulary covered by flashcards: 34.1%
#
# Verbs needing new flashcards:
# ['find', 'show', 'beat', 'tell', 'sound'] ...
#
# Vocabulary needing new flashcards:
# ['like', 'unexpected', 'good', 'weekend', 'yes'] ...
#
# Vocabulary Analysis for story_better_than_a_movie:
# Assigned phrases: 28
# Verb coverage: 33.3%
# Vocabulary coverage: 34.1%
# Missing verbs: 22
# Missing vocabulary: 56
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 42.9%
# Target vocabulary covered by flashcards: 28.8%
#
# Verbs needing new flashcards:
# ['find', 'sound', 'know', 'share', 'work'] ...
#
# Vocabulary needing new flashcards:
# ['first', 'child', 'yes', 'definitely', 'absolutely'] ...
#
# Vocabulary Analysis for story_teaching_music:
# Assigned phrases: 28
# Verb coverage: 42.9%
# Vocabulary coverage: 28.8%
# Missing verbs: 20
# Missing vocabulary: 74
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 33.3%
# Target vocabulary covered by flashcards: 34.5%
#
# Verbs needing new flashcards:
# ['improve', 'find', 'excuse', 'continue', 'check'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'happy', 'manager', 'around', 'sir'] ...
#
# Vocabulary Analysis for story_the_power_cut:
# Assigned phrases: 25
# Verb coverage: 33.3%
# Vocabulary coverage: 34.5%
# Missing verbs: 30
# Missing vocabulary: 72
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 41.9%
# Target vocabulary covered by flashcards: 29.0%
#
# Verbs needing new flashcards:
# ['find', 'wake', 'calm', 'excuse', 'ask'] ...
#
# Vocabulary needing new flashcards:
# ['like', 'unexpected', 'souvenir', 'yes', 'while'] ...
#
# Vocabulary Analysis for story_a_missed_stop:
# Assigned phrases: 23
# Verb coverage: 41.9%
# Vocabulary coverage: 29.0%
# Missing verbs: 25
# Missing vocabulary: 76
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 40.6%
# Target vocabulary covered by flashcards: 35.2%
#
# Verbs needing new flashcards:
# ['find', 'call', 'wake', 'enjoy', 'fit'] ...
#
# Vocabulary needing new flashcards:
# ['good', 'wine', 'two', 'yes', 'absolutely'] ...
#
# Vocabulary Analysis for story_unexpected_wedding_guests:
# Assigned phrases: 22
# Verb coverage: 40.6%
# Vocabulary coverage: 35.2%
# Missing verbs: 19
# Missing vocabulary: 57
# === VOCABULARY COVERAGE ANALYSIS ===
# Target verbs covered by flashcards: 35.1%
# Target vocabulary covered by flashcards: 36.5%
#
# Verbs needing new flashcards:
# ['like', 'pile', 'manage', 'hold', 'visit'] ...
#
# Vocabulary needing new flashcards:
# ['challenge', 'manager', 'mind', 'boss', 'first'] ...
#
# Vocabulary Analysis for story_workplace_stress_vacation:
# Assigned phrases: 24
# Verb coverage: 35.1%
# Vocabulary coverage: 36.5%
# Missing verbs: 24
# Missing vocabulary: 54

# %%
phrase_index['verb_index']['cook']
# Out:
# [225, 421, 358, 398, 463, 52, 468, 246, 533, 376]

# %%
phrase_index['phrases'][590]
# Out:
# "Don't you hate waking up early in the morning?"

# %%
story_index['verb_index']
# Out:
# {'help': ['story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_the_marathon',
#   'story_the_power_cut',
#   'story_winter_in_sweden',
#   'story_the_birthday_party'],
#  'can': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_the_power_cut',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'plan': ['story_teaching_music',
#   'story_midnight_garden_mystery',
#   'story_winter_in_sweden',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_camping_trip_gone_awry',
#   'story_the_birthday_party'],
#  'do': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_forgetful_diver',
#   'story_a_missed_stop',
#   'story_unexpected_career_change',
#   'story_workplace_stress_vacation',
#   'story_teaching_music',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_midnight_garden_mystery',
#   'story_the_birthday_party',
#   'story_road_trip',
#   'story_winter_in_sweden'],
#  'would': ['story_a_fishing_trip',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_the_marathon',
#   'story_better_than_a_movie',
#   'story_the_power_cut',
#   'story_the_birthday_party'],
#  'love': ['story_teaching_music',
#   'story_a_missed_stop',
#   'story_midnight_garden_mystery',
#   'story_the_marathon',
#   'story_the_birthday_party'],
#  'have': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_forgetful_diver',
#   'story_a_missed_stop',
#   'story_unexpected_career_change',
#   'story_workplace_stress_vacation',
#   'story_teaching_music',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_better_than_a_movie',
#   'story_midnight_garden_mystery',
#   'story_the_birthday_party',
#   'story_road_trip',
#   'story_winter_in_sweden'],
#  'be': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_forgetful_diver',
#   'story_a_missed_stop',
#   'story_unexpected_career_change',
#   'story_workplace_stress_vacation',
#   'story_teaching_music',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_midnight_garden_mystery',
#   'story_the_birthday_party',
#   'story_road_trip',
#   'story_winter_in_sweden'],
#  'think': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_the_power_cut',
#   'story_winter_in_sweden',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'sound': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'hope': ['story_a_missed_stop',
#   'story_team_spirit',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_the_power_cut',
#   'story_winter_in_sweden',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'work': ['story_teaching_music',
#   'story_midnight_garden_mystery',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_the_power_cut',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party'],
#  'let': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_a_missed_stop',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'make': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_missed_stop',
#   'story_midnight_garden_mystery',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'need': ['story_teaching_music',
#   'story_workplace_stress_vacation',
#   'story_midnight_garden_mystery',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_unexpected_career_change',
#   'story_camping_trip_gone_awry',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'start': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_job_interview_gone_wrong',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_winter_in_sweden',
#   'story_the_birthday_party'],
#  'should': ['story_brussels_blend',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_a_missed_stop',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'order': ['story_brussels_blend', 'story_the_birthday_party'],
#  'forget': ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_job_interview_gone_wrong',
#   'story_road_trip',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'will': ['story_brussels_blend',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'call': ['story_brussels_blend',
#   'story_job_interview_gone_wrong',
#   'story_the_birthday_party',
#   'story_unexpected_wedding_guests'],
#  'remember': ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_a_missed_stop',
#   'story_midnight_garden_mystery',
#   'story_workplace_stress_vacation',
#   'story_rainy_football_match',
#   'story_unexpected_career_change',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party'],
#  'book': ['story_road_trip',
#   'story_better_than_a_movie',
#   'story_winter_in_sweden',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'get': ['story_brussels_blend',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_the_power_cut',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'might': ['story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'hurry': ['story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'panic': ['story_the_birthday_party'],
#  'come': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_a_missed_stop',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_the_power_cut',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'try': ['story_brussels_blend',
#   'story_a_fishing_trip',
#   'story_a_missed_stop',
#   'story_job_interview_gone_wrong',
#   'story_the_power_cut',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party'],
#  'expect': ['story_the_birthday_party'],
#  'send': ['story_the_birthday_party', 'story_team_spirit'],
#  'cook': ['story_the_birthday_party'],
#  'shop': ['story_unexpected_wedding_guests',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'go': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_missed_stop',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_the_power_cut',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'give': ['story_teaching_music',
#   'story_midnight_garden_mystery',
#   'story_better_than_a_movie',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party'],
#  'look': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_a_missed_stop',
#   'story_job_interview_gone_wrong',
#   'story_workplace_stress_vacation',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_rainy_football_match',
#   'story_the_power_cut',
#   'story_unexpected_career_change',
#   'story_camping_trip_gone_awry',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'pull': ['story_the_birthday_party'],
#  'believe': ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_midnight_garden_mystery',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_wedding_guests',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party'],
#  'know': ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_the_birthday_party'],
#  'enjoy': ['story_unexpected_wedding_guests',
#   'story_the_birthday_party',
#   'story_a_fishing_trip',
#   'story_forgetful_diver'],
#  'see': ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_a_missed_stop',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_the_power_cut',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_birthday_party',
#   'story_forgetful_diver'],
#  'turn': ['story_teaching_music',
#   'story_team_spirit',
#   'story_midnight_garden_mystery',
#   'story_road_trip',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_the_birthday_party'],
#  'happen': ['story_job_interview_gone_wrong',
#   'story_the_marathon',
#   'story_the_birthday_party',
#   'story_team_spirit'],
#  'move': ['story_camping_trip_gone_awry',
#   'story_the_birthday_party',
#   'story_workplace_stress_vacation'],
#  'tackle': ['story_the_birthday_party'],
#  'pack': ['story_camping_trip_gone_awry',
#   'story_a_missed_stop',
#   'story_forgetful_diver',
#   'story_unexpected_wedding_guests'],
#  "'ve": ['story_teaching_music',
#   'story_a_fishing_trip',
#   'story_a_missed_stop',
#   'story_workplace_stress_vacation',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues',
#   'story_the_power_cut',
#   'story_midnight_garden_mystery',
#   'story_forgetful_diver'],
#  'grab': ['story_brussels_blend',
#   'story_a_missed_stop',
#   'story_job_interview_gone_wrong',
#   'story_rainy_football_match',
#   'story_the_power_cut',
#   'story_camping_trip_gone_awry'],
#  'meet': ['story_camping_trip_gone_awry',
#   'story_unexpected_career_change',
#   'story_team_spirit',
#   'story_better_than_a_movie'],
#  'finish': ['story_camping_trip_gone_awry', 'story_sunset_wedding_blues'],
#  'wake': ['story_a_missed_stop',
#   'story_unexpected_wedding_guests',
#   'story_road_trip',
#   'story_camping_trip_gone_awry',
#   'story_forgetful_diver'],
#  'say': ['story_a_missed_stop',
#   'story_team_spirit',
#   'story_rainy_football_match',
#   'story_the_power_cut',
#   'story_unexpected_career_change',
#   'story_camping_trip_gone_awry',
#   'story_sunset_wedding_blues'],
#  'pour': ['story_camping_trip_gone_awry', 'story_rainy_football_match'],
#  'could': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_a_missed_stop',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_midnight_garden_mystery',
#   'story_forgetful_diver'],
#  'sleep': ['story_camping_trip_gone_awry'],
#  'keep': ['story_camping_trip_gone_awry',
#   'story_job_interview_gone_wrong',
#   'story_rainy_football_match'],
#  'soak': ['story_camping_trip_gone_awry'],
#  'heat': ['story_camping_trip_gone_awry'],
#  'want': ['story_brussels_blend',
#   'story_teaching_music',
#   'story_team_spirit',
#   'story_workplace_stress_vacation',
#   'story_job_interview_gone_wrong',
#   'story_winter_in_sweden',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie',
#   'story_camping_trip_gone_awry',
#   'story_the_power_cut',
#   'story_midnight_garden_mystery',
#   'story_forgetful_diver'],
#  'check': ['story_a_fishing_trip',
#   'story_team_spirit',
#   'story_winter_in_sweden',
#   'story_unexpected_wedding_guests',
#   'story_the_marathon',
#   'story_the_power_cut',
#   'story_camping_trip_gone_awry',
#   'story_forgetful_diver'],
#  'tell': ['story_camping_trip_gone_awry', 'story_better_than_a_movie'],
#  'eat': ['story_camping_trip_gone_awry',
#   'story_a_missed_stop',
#   'story_unexpected_wedding_guests'],
#  'pick': ['story_a_fishing_trip', 'story_team_spirit'],
#  'buy': ['story_unexpected_wedding_guests',
#   'story_a_missed_stop',
#   'story_a_fishing_trip',
#   'story_unexpected_career_change'],
#  'close': ['story_a_fishing_trip', 'story_unexpected_career_change'],
#  'worry': ['story_a_fishing_trip',
#   'story_unexpected_wedding_guests',
#   'story_winter_in_sweden',
#   'story_sunset_wedding_blues',
#   'story_forgetful_diver'],
#  'stop': ['story_rainy_football_match',
#   'story_a_fishing_trip',
#   'story_team_spirit'],
#  'lose': ['story_winter_in_sweden',
#   'story_a_fishing_trip',
#   'story_unexpected_career_change'],
#  'follow': ['story_winter_in_sweden', 'story_a_fishing_trip'],
#  'bring': ['story_winter_in_sweden',
#   'story_a_fishing_trip',
#   'story_team_spirit'],
#  'pass': ['story_a_fishing_trip'],
#  'retrace': ['story_a_fishing_trip'],
#  'ask': ['story_a_missed_stop',
#   'story_a_fishing_trip',
#   'story_rainy_football_match',
#   'story_winter_in_sweden',
#   'story_workplace_stress_vacation'],
#  'end': ['story_a_fishing_trip'],
#  'lead': ['story_brussels_blend',
#   'story_road_trip',
#   'story_a_missed_stop',
#   'story_a_fishing_trip'],
#  'bite': ['story_a_fishing_trip'],
#  'prepare': ['story_job_interview_gone_wrong',
#   'story_teaching_music',
#   'story_midnight_garden_mystery'],
#  'break': ['story_job_interview_gone_wrong'],
#  'run': ['story_job_interview_gone_wrong',
#   'story_the_marathon',
#   'story_forgetful_diver'],
#  'arrive': ['story_job_interview_gone_wrong'],
#  'enter': ['story_job_interview_gone_wrong'],
#  'spill': ['story_job_interview_gone_wrong'],
#  'clean': ['story_job_interview_gone_wrong'],
#  'wait': ['story_a_missed_stop',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_career_change',
#   'story_the_power_cut',
#   'story_forgetful_diver'],
#  'knock': ['story_the_power_cut', 'story_job_interview_gone_wrong'],
#  'stumble': ['story_job_interview_gone_wrong', 'story_road_trip'],
#  'top': ['story_job_interview_gone_wrong'],
#  'explain': ['story_job_interview_gone_wrong'],
#  'apologize': ['story_job_interview_gone_wrong'],
#  'learn': ['story_winter_in_sweden',
#   'story_job_interview_gone_wrong',
#   'story_unexpected_career_change',
#   'story_better_than_a_movie'],
#  'take': ['story_team_spirit',
#   'story_job_interview_gone_wrong',
#   'story_the_power_cut',
#   'story_unexpected_career_change',
#   'story_brussels_blend',
#   'story_sunset_wedding_blues',
#   'story_workplace_stress_vacation'],
#  'talk': ['story_job_interview_gone_wrong',
#   'story_unexpected_career_change',
#   'story_sunset_wedding_blues',
#   'story_workplace_stress_vacation',
#   'story_forgetful_diver'],
#  'use': ['story_brussels_blend',
#   'story_job_interview_gone_wrong',
#   'story_rainy_football_match',
#   'story_forgetful_diver'],
#  'hear': ['story_teaching_music',
#   'story_team_spirit',
#   'story_workplace_stress_vacation',
#   'story_the_marathon',
#   'story_road_trip',
#   'story_unexpected_career_change',
#   'story_brussels_blend',
#   'story_midnight_garden_mystery'],
#  'teach': ['story_teaching_music', 'story_midnight_garden_mystery'],
#  'share': ['story_teaching_music', 'story_midnight_garden_mystery'],
#  'sign': ['story_teaching_music',
#   'story_the_marathon',
#   'story_midnight_garden_mystery',
#   'story_team_spirit'],
#  'include': ['story_teaching_music', 'story_midnight_garden_mystery'],
#  'realize': ['story_teaching_music', 'story_midnight_garden_mystery'],
#  'find': ['story_teaching_music',
#   'story_a_missed_stop',
#   'story_unexpected_wedding_guests',
#   'story_the_power_cut',
#   'story_better_than_a_movie',
#   'story_winter_in_sweden',
#   'story_midnight_garden_mystery'],
#  'fix': ['story_the_power_cut',
#   'story_teaching_music',
#   'story_midnight_garden_mystery'],
#  'join': ['story_teaching_music',
#   'story_team_spirit',
#   'story_the_marathon',
#   'story_unexpected_career_change',
#   'story_winter_in_sweden',
#   'story_midnight_garden_mystery'],
#  'shall': ['story_teaching_music', 'story_midnight_garden_mystery'],
#  'rain': ['story_rainy_football_match'],
#  'affect': ['story_rainy_football_match'],
#  'train': ['story_the_marathon', 'story_rainy_football_match'],
#  'stay': ['story_the_marathon',
#   'story_rainy_football_match',
#   'story_a_missed_stop',
#   'story_team_spirit'],
#  'control': ['story_rainy_football_match'],
#  'focus': ['story_rainy_football_match', 'story_forgetful_diver'],
#  'postpone': ['story_rainy_football_match'],
#  'face': ['story_rainy_football_match', 'story_workplace_stress_vacation'],
#  'adjust': ['story_rainy_football_match'],
#  'slip': ['story_rainy_football_match'],
#  "'s": ['story_rainy_football_match'],
#  'struggle': ['story_rainy_football_match'],
#  'win': ['story_rainy_football_match'],
#  'pay': ['story_rainy_football_match', 'story_unexpected_career_change'],
#  'celebrate': ['story_unexpected_wedding_guests',
#   'story_rainy_football_match',
#   'story_team_spirit'],
#  'show': ['story_rainy_football_match',
#   'story_road_trip',
#   'story_better_than_a_movie'],
#  'handle': ['story_the_power_cut',
#   'story_the_marathon',
#   'story_rainy_football_match',
#   'story_unexpected_career_change'],
#  'marry': ['story_sunset_wedding_blues'],
#  'getting': ['story_sunset_wedding_blues'],
#  'figure': ['story_sunset_wedding_blues', 'story_the_marathon'],
#  'head': ['story_sunset_wedding_blues'],
#  'inspire': ['story_sunset_wedding_blues'],
#  'support': ['story_sunset_wedding_blues',
#   'story_the_marathon',
#   'story_unexpected_career_change'],
#  'speak': ['story_winter_in_sweden', 'story_sunset_wedding_blues'],
#  'feel': ['story_team_spirit',
#   'story_the_marathon',
#   'story_the_power_cut',
#   'story_sunset_wedding_blues',
#   'story_workplace_stress_vacation',
#   'story_forgetful_diver'],
#  'hurt': ['story_the_marathon', 'story_team_spirit'],
#  'got': ['story_team_spirit'],
#  'injure': ['story_team_spirit'],
#  'play': ['story_team_spirit', 'story_better_than_a_movie'],
#  'visit': ['story_winter_in_sweden',
#   'story_workplace_stress_vacation',
#   'story_team_spirit'],
#  'drive': ['story_team_spirit'],
#  'appreciate': ['story_team_spirit'],
#  'wish': ['story_team_spirit'],
#  'surround': ['story_team_spirit'],
#  'practice': ['story_winter_in_sweden'],
#  'hike': ['story_winter_in_sweden'],
#  'freeze': ['story_winter_in_sweden', 'story_brussels_blend'],
#  'communicate': ['story_winter_in_sweden'],
#  'dive': ['story_forgetful_diver'],
#  'leave': ['story_unexpected_wedding_guests', 'story_forgetful_diver'],
#  'explore': ['story_a_missed_stop',
#   'story_forgetful_diver',
#   'story_better_than_a_movie'],
#  'overslept': ['story_forgetful_diver'],
#  'solve': ['story_forgetful_diver'],
#  'borrow': ['story_forgetful_diver'],
#  'save': ['story_the_power_cut', 'story_forgetful_diver'],
#  'promise': ['story_the_marathon', 'story_forgetful_diver'],
#  'restructure': ['story_unexpected_career_change'],
#  'consider': ['story_workplace_stress_vacation',
#   'story_unexpected_career_change'],
#  'track': ['story_unexpected_career_change'],
#  'build': ['story_unexpected_career_change'],
#  'fail': ['story_unexpected_career_change'],
#  'succeed': ['story_unexpected_career_change'],
#  'decide': ['story_a_missed_stop', 'story_unexpected_career_change'],
#  'research': ['story_unexpected_career_change'],
#  'park': ['story_brussels_blend'],
#  'hit': ['story_brussels_blend'],
#  'jump': ['story_brussels_blend'],
#  'steer': ['story_brussels_blend'],
#  'push': ['story_brussels_blend', 'story_workplace_stress_vacation'],
#  'budge': ['story_brussels_blend'],
#  'walk': ['story_brussels_blend'],
#  'warm': ['story_brussels_blend'],
#  'bundle': ['story_brussels_blend'],
#  'guess': ['story_brussels_blend',
#   'story_a_missed_stop',
#   'story_the_power_cut'],
#  'imagine': ['story_brussels_blend'],
#  'convince': ['story_road_trip'],
#  'cancel': ['story_road_trip'],
#  'offer': ['story_road_trip'],
#  'ruin': ['story_road_trip'],
#  'calm': ['story_a_missed_stop', 'story_road_trip'],
#  'compare': ['story_road_trip'],
#  'trust': ['story_road_trip'],
#  'achieve': ['story_the_marathon'],
#  'put': ['story_the_marathon'],
#  'volunteer': ['story_the_marathon'],
#  'hand': ['story_the_marathon'],
#  'disappoint': ['story_the_marathon'],
#  'catch': ['story_a_missed_stop', 'story_better_than_a_movie'],
#  'sell': ['story_better_than_a_movie'],
#  'create': ['story_better_than_a_movie'],
#  'mean': ['story_better_than_a_movie'],
#  'beat': ['story_better_than_a_movie'],
#  'watch': ['story_better_than_a_movie'],
#  'edit': ['story_better_than_a_movie'],
#  'improve': ['story_the_power_cut'],
#  'seem': ['story_the_power_cut'],
#  'double': ['story_the_power_cut'],
#  'verify': ['story_the_power_cut'],
#  'flicker': ['story_the_power_cut'],
#  'notice': ['story_the_power_cut'],
#  'cover': ['story_the_power_cut'],
#  'excuse': ['story_the_power_cut', 'story_a_missed_stop'],
#  'cause': ['story_the_power_cut'],
#  'continue': ['story_the_power_cut'],
#  'miss': ['story_a_missed_stop'],
#  'collect': ['story_a_missed_stop'],
#  'relax': ['story_workplace_stress_vacation', 'story_a_missed_stop'],
#  'escape': ['story_a_missed_stop'],
#  'discover': ['story_a_missed_stop'],
#  'fit': ['story_unexpected_wedding_guests'],
#  'avert': ['story_unexpected_wedding_guests'],
#  'deal': ['story_workplace_stress_vacation'],
#  'quit': ['story_workplace_stress_vacation'],
#  'hold': ['story_workplace_stress_vacation'],
#  'clear': ['story_workplace_stress_vacation'],
#  'like': ['story_workplace_stress_vacation'],
#  'pile': ['story_workplace_stress_vacation'],
#  'approve': ['story_workplace_stress_vacation'],
#  'stress': ['story_workplace_stress_vacation'],
#  'manage': ['story_workplace_stress_vacation']}

# %%
save_json(phrase_key_to_best_story_match, "./phrase_key_to_best_story_match.json")

# %%
len(LM1000_phrases)

# %%
for phrase_key in phrase_to_stories:
    #find best story
    best_story = list(phrase_key_to_best_story_match[phrase_key].keys())[0]
    current_story = phrase_to_stories[phrase_key][0]
    if best_story != current_story:
        print(f"{phrase_key} : current {current_story} - best {best_story}")

# %%
phrase_key_to_best_story_match

# %%
# place
from src.nlp import find_missing_vocabulary, get_vocab_dictionary_from_phrases, get_vocab_dict_from_dialogue
notebook_dir = Path().absolute() 
story_dir = notebook_dir.parent / "outputs" / "stories"
results = dict()
for story_name in all_stories:
    story_path = story_dir / story_name / f"{story_name}.json"
    story_dialogue = load_json(story_path)
    print(f"Doing story: {story_name}")
    vocab_flashcards = get_vocab_dictionary_from_phrases(df_opt.query(f"story == '{story_name}'")['EnglishText'])
    vocab_story = get_vocab_dict_from_dialogue(story_dialogue)
    missing_vocab = find_missing_vocabulary(vocab_flashcards, vocab_story)
    results[story_name] = missing_vocab

# %%
# sort so stories with fewest missing vocab come out top
coverage_dict = dict()
for story in results:
    verb_coverage = results[story]['coverage_stats']['verb_coverage']
    vocab_coverage = results[story]['coverage_stats']['vocab_coverage']
    total_coverage = verb_coverage + vocab_coverage
    coverage_dict[story] = total_coverage

sorted_dict = dict(sorted(coverage_dict.items(), key=lambda item: item[1], reverse=True))
story_name_order = list(sorted_dict.keys())

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from typing import Set, List, Dict, Tuple
from src.nlp import optimize_stories_and_phrases

# %%
df_opt2 = optimize_stories_and_phrases(df_opt, story_name_order)

# %%
df_opt2.to_csv("STORY AND PHRASE ORDER.csv")

# %%
df_opt2.groupby('story').count().cumsum()

# %%
plot_vocabulary_growth(df_opt2['EnglishText'])

# %%
plot_vocabulary_growth(df_opt['EnglishText'])

# %% [markdown]
# # Save as JSON file

# %%
import pandas as pd

df = pd.read_csv("STORY AND PHRASE ORDER.csv")

# %%
json_dict = df.groupby("story").apply(lambda x: [phrase for phrase in x['EnglishText']]).to_dict()

# %%
config.GCS_PRIVATE_BUCKET

# %%
upload_to_gcs(obj = json_dict,
            bucket_name=config.GCS_PRIVATE_BUCKET,
            file_name = "collections/LM1000/LM1000-with-stories.json")
